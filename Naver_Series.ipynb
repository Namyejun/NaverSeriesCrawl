# %%
import requests
from bs4 import BeautifulSoup as BS
import re
import pandas as pd
import threading
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import json
import pickle
from tqdm import tqdm
import time

# %%
start, end = 1, 1 # 시작 페이지부터 종료 페이지 설정
page_range = [i for i in range(start, end + 1)]

# %%
def get_chrome_driver():
    # 1. 브라우저 옵션 세팅
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('headless') # 브라우저가 뜨지 않고 실행

    # 2. driver 생성
    driver = webdriver.Chrome(
        service = Service(ChromeDriverManager().install()),
        options = chrome_options
    )
    return driver

# %%
def detail(url, productNo, page_size, product): # detail url과 productNo, 가져올 댓글의 개수를 파라미터로 받음
    driver = get_chrome_driver()
    driver.get(url)
    page = driver.page_source
    soup = BS(page, "html.parser")

    try:
        title = soup.select_one("#content > div.end_head > h2").text.replace("\n"," ").strip()
    except:
        title = None
    try:
        star_score = float(soup.select_one("#content > div.end_head > div.score_area > em").text.replace("\n"," ").replace(" ", ""))
    except:
        star_score = None
    try:
        liked = int(soup.select_one("#content > div.end_head > div.user_action_area > ul > li:nth-child(2) > div > a > em").text.replace("\n"," ").replace(" ", ""))
    except:
        liked = None
    try:
        author = soup.select_one("#content > ul.end_info.NE\=a\:nvi > li > ul > li:nth-child(3) > a").text.replace("\n"," ").strip()
    except:
        author = None
    try:
        publisher = soup.select_one("#content > ul.end_info.NE\=a\:nvi > li > ul > li:nth-child(4) > a").text.replace("\n"," ").strip()
    except:
        publisher = None
    try:
        age_rating = soup.select_one("#content > ul.end_info.NE\=a\:nvi > li > ul > li:nth-child(5)").text.replace("\n"," ").strip()
    except:
        age_rating = None
    try:
        rule = re.compile("[0-9]+_[0_9]")
        sObjectId = re.findall(rule, str(soup)[str(soup).find("sObjectId"):str(soup).find("sObjectId")+22])[0]
    except:
        sObjectId = None

    URL = f"https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=series5&templateId=web&pool=cbox12&_cv=20230425152100&_callback=jQuery34103220350950592199_1682763418916&lang=ko&country=&objectId={sObjectId}&categoryId=&pageSize={page_size}&indexSize=5&groupId=&listType=OBJECT&pageType=default&page=1&initialize=true&followSize=5&userType=&useAltSort=true&replyPageSize=10&_=1682763418918"
    
    header = {
        "referer": f"https://series.naver.com/novel/detail.series?productNo={productNo}", # 지우면 안됨
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36" # 지우면 안됨
    }
    
    response = requests.get(URL, headers=header)
    data = response.content
    
    jquery = data.decode(encoding='UTF-8', errors='strict')
    
    start = jquery.find('{')
    end = jquery[::-1].find("}")
    json_data = jquery[start : -end]
    
    dict_data = json.loads(json_data)

    commentList = dict_data['result']['commentList']

    comment_list = [] # 한 작품의 댓글을 담을 리스트
    for comment in commentList:
        comment_dict = {} # 한 댓글의 정보를 담을 딕셔너리
        comment_dict['contents'] = re.sub("\s{2,}", " ", comment['contents'].replace("\n", ""))
        comment_dict['sympathyCount'] = int(comment['sympathyCount'])
        comment_dict['antipathyCount'] = int(comment['antipathyCount'])
        comment_list.append(comment_dict)

    info = {} # 한 작품의 정보가 담긴 딕셔너리 만들기
    info['title'] = title
    info['star_score'] = star_score
    info['liked'] = liked
    info['author'] = author
    info['publisher'] = publisher
    info['age_rating'] = age_rating
    info['sObjectId'] = sObjectId
    info['comment_list'] = comment_list

    product[productNo] = info

# %% [markdown]
# dict 정보
# - product
# - productNo : string
#     - title : string
#     - star_score : float
#     - liked : int
#     - author : string
#     - publisher : string
#     - age_rating : string
#     - sObjectId : string
#     - comment_list : list
#
# - comment_list
#     - contents : string
#     - sympathyCount : int
#     - antipathyCount : int

# %%
threads = []
product = {}
for page in tqdm(page_range): # 총 3072 페이지 존재
    NAVER_SERIES_URL = f"https://series.naver.com/novel/categoryProductList.series?categoryTypeCode=all&page={page}" # 페이지에 따른 작품 가져오기

    reponse = requests.get(NAVER_SERIES_URL)
    html_code = reponse.content

    soup = BS(html_code, "html.parser") # 파싱

    items = soup.select("div#content > div.lst_thum_wrap > ul.lst_list > li > div.cont.cont_v2 > h3 > a") # 작품들 가져오기

    for item in items: # 한 페이지 내의 작품들 25개씩임
        href = "https://series.naver.com" + item['href']
        productNo = re.findall(re.compile("[0-9]+"), href)[0]
        t = threading.Thread(target = detail, args = (href, productNo, 10, product))
        t.start()
        threads.append(t)
    time.sleep(1)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.53s/it]

# %%
for thread in tqdm(threads):
    thread.join()
# Out:
# 100%|██████████| 25/25 [00:16<00:00,  1.52it/s]

# %%
product
# Out:
# {'9440917': {'title': '히든 피스로 전설 기사',
#   'star_score': 8.3,
#   'liked': 1,
#   'author': 'S.Captain',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '498891_0',
#   'comment_list': [{'contents': '주69시간제로 성큼 다가온 이세계 빙의 위험성',
#     'sympathyCount': 132,
#     'antipathyCount': 12},
#    {'contents': '아...유치하네...', 'sympathyCount': 51, 'antipathyCount': 7},
#    {'contents': '짜증나서 댓글 쓰는데 레벨에대한 설정을좀 제대로 해애할꺼같음 처음 검술얻었을때는 실제수준이아니구 육체에대한 강함기준으로 가는것 같더니 점점갈수록 오류가 나더니.이번화에서는 기존 육체강화에 8배인데 레벨 2상승 ? 너무 수치상승이 괴랄했음 뭐 계속 이렇게.올리는게힘들다 설정에 그만큼 강하다라는설정이면 처음 세계관최강자설정이 너무 말도안댐 설정좀 자세히 생각하고 글을써주셨으면 하는바람',
#     'sympathyCount': 24,
#     'antipathyCount': 0},
#    {'contents': '이 책의 제목은 잘못되었다.히든피스로 주인공 강탈. 이게 맞다.',
#     'sympathyCount': 21,
#     'antipathyCount': 0},
#    {'contents': "29화 16%쯤 켈베르트가 과거 회상하는 씬에서'명성 높은 가문의 아들로 태어나 어린 시절부터 가족들의 기대를 한 몸에 받았고, 자신 역시 그 기대에 부응할 만한 모습을 보여주었다.주변 사람 모두가 입이 마르도록 그의 실력과 인품을 칭송했고, 과연 드높은 가문의 명성에 어울리는 인재라는 평이 자자했다.'라고 묘사... 아르민 어린시절이랑 맞지않아 수정이 필요할듯 싶습니다.",
#     'sympathyCount': 19,
#     'antipathyCount': 0},
#    {'contents': '니나는 이제 마네킹되었나', 'sympathyCount': 19, 'antipathyCount': 0},
#    {'contents': '이건 솔직히 개연성이 없어도 너무 없는데? 가끔 머리가 확 도는 성격이긴 하지만 기본적으론 계산에 뛰어나며 용병단에 이득이 되는 쪽으로 움직여왔던 단장이 이미 완벽하게 전쟁을 준비하고 전력도 막강하다는걸 알면서도 왜 남작쪽에 붙었으며.주인공도 가족처럼 지내왔다는 용병단 일원들이 패배할것이 확정된 전장에 참가하겠다는 걸 원작 주인공이 있다는 이유만으로 말리지 않는 것이 무슨 소설에 미친 사이코패스같이 그린건 정말 이해가 안되는데?적어도 주인공은 반대 했는데 어쩔수 없는 상황을 만들어서 개연성을 챙겼어야지.그게 힘든 것도 아니고, 작가가 아닌 내가 지금 잠깐만 생각해봐도 감옥에 붙잡혔을때 명분이라도 챙긴답시고 용병단에 누명씌우고 죽일려던거 단장이 금패를 가진 실력자라는 걸 알고서는 곧 일어날것 같은 전쟁에 억지로 참전 하는걸 조건으로 풀어준다거나 하는 개연성을 집어넣을 수 있었을텐데? 이건 작가의 순수한 역량부족이고 소설 속 개연성의 커다란 오류이다.',
#     'sympathyCount': 17,
#     'antipathyCount': 0},
#    {'contents': '이후에도 그럴지는 모르겠지만"(?)" 이 부호를 너무 남발하여 가볍고 유치한 글처럼 느껴지게 만듭니다.',
#     'sympathyCount': 14,
#     'antipathyCount': 1},
#    {'contents': '이름 언제 불렀어..?', 'sympathyCount': 13, 'antipathyCount': 1},
#    {'contents': '숏소드 8실버 사놓고 자꾸 6실버래..제값주고 8실버에사고 덤으로 전설검 받아온거 아닌가?',
#     'sympathyCount': 13,
#     'antipathyCount': 1}]},
#  '8294718': {'title': '귀환 첫날 아포칼립스가 열렸다',
#   'star_score': 8.5,
#   'liked': 16,
#   'author': '편몽',
#   'publisher': '라온E&M',
#   'age_rating': '전체 이용가',
#   'sObjectId': '464057_0',
#   'comment_list': [{'contents': '설명에 이능력 멀쩡한 상태로 귀환한다더니 이걸 이렇게 사기를 치네. 이능력 하나는 멀쩡한건 맞네',
#     'sympathyCount': 64,
#     'antipathyCount': 5},
#    {'contents': '아니 평화로운 세상이라고 가져온 능력이 오히려 바보 같은 선택같은데?... 아니 아무런 작업없이 강화된 식칼을 팔면 어떻게 되겠음... 바로 어디 범죄조직 끌려가서 마약 강화나 강제로 하거나 국방부 끌려가서 무기 강화 강제로 하고나 51구역에 납치당해서 외계인이랑 싸비싸바하든 강화인간을 만들든 실험이나 당하겠지',
#     'sympathyCount': 51,
#     'antipathyCount': 8},
#    {'contents': '결국 이것도 다운그레이드 구나고구마 들어간다 입 벌려라~',
#     'sympathyCount': 46,
#     'antipathyCount': 5},
#    {'contents': '아포칼립스에서 식량난 오질텐데 하필 대가가 포만감 ㅋㅋ 좃대써!',
#     'sympathyCount': 34,
#     'antipathyCount': 1},
#    {'contents': '국밥은 다 먹게 해줘라...', 'sympathyCount': 34, 'antipathyCount': 1},
#    {'contents': '달피아 아재 짬바 ㅋㅋㅋ', 'sympathyCount': 21, 'antipathyCount': 1},
#    {'contents': '이제 대식이가 지혁아… &lt;&lt;&lt;만 해도 웃기다고 ㅋㅋㅋㅋㅋㅋㅋ',
#     'sympathyCount': 20,
#     'antipathyCount': 1},
#    {'contents': '마지막 부디... 무사하시길 ㅋㅋㅋㅋㅋㅋ 알면 주인공한테 알려줘 ㅋㅋ',
#     'sympathyCount': 18,
#     'antipathyCount': 0},
#    {'contents': '극한상황에 인간 본성 나오는데 저런 인격자는 동료원픽이지',
#     'sympathyCount': 17,
#     'antipathyCount': 0},
#    {'contents': '상상에서도 소심하군 당연히 와락 포옹을 노려야지 ㅋㅋ 고긴데',
#     'sympathyCount': 15,
#     'antipathyCount': 1}]},
#  '9083751': {'title': '마이클 조던 보다 농구 잘함',
#   'star_score': 7.6,
#   'liked': None,
#   'author': '자유수달',
#   'publisher': '라온E&M',
#   'age_rating': '전체 이용가',
#   'sObjectId': '488008_0',
#   'comment_list': [{'contents': '야 너무 돌아왔잖아',
#     'sympathyCount': 13,
#     'antipathyCount': 0}]},
#  '9653969': {'title': '당가암룡',
#   'star_score': 8.8,
#   'liked': 14,
#   'author': '처량한날',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '505218_0',
#   'comment_list': [{'contents': '101화까지 다본 선발대입니다.1. 시리즈기준 9점급 충분합니다.2. 초반 쾌속진행후 외유를 돌며 빌드업하는 이벤트들이 촘촘하고짜임새 있습니다. 조금씩 겹쳐지며 80화부근서 폭발하며 본격적인행보가 나옵니다.특히 그부근 한회차는 역대급 뽕차오르는 서사의폭발이 있습니다.3.80화이후 수신을 끝내고 제가를 하며 치국으로 이어질듯한데다양한 서사가 잘 어우러집니다.큰틀의 이야기와 작은 이야기들이잘 버무러짐4.약간 선협요소가 있으나 정통구무협 스럽고 무공경지 묘사나심득의 체화가 수준있습니다. 강해지는 맛이 있음.5. 다소 불친절한 설정해설은 읽다보면 자연스레 보충되는데초중반 약간 적응안될땐 진입벽이 있습니다.가령 일반무협의 경지상 고수취급 용어가 어기응령이고삼정조화가 초고수급 용어입니다. 작중 삼정조화는 한방파 한명급인걸로 보여지고요.지금 주인공이 어기응령끝자락 삼정조화 목전.6. 캐릭터성 관계성이 어찌보면 복잡 자세하고 어찌보면 좀 뜬금없는 부분이 있음',
#     'sympathyCount': 72,
#     'antipathyCount': 8},
#    {'contents': '와 전개 신선하네요.예상 못했다. 도울줄 알았는데 ㄷㄷ',
#     'sympathyCount': 14,
#     'antipathyCount': 3},
#    {'contents': '친남매간의 불륜을 넘는 사련의 잉태물인데 작가가 하도 반전의 뒤집기에 능해 단정짓기가 애매하네. 지켜봐야 할 듯.',
#     'sympathyCount': 11,
#     'antipathyCount': 3},
#    {'contents': '와.....이런 식의 가화만사성 이루는거야? ',
#     'sympathyCount': 11,
#     'antipathyCount': 3}]},
#  '9455456': {'title': '필드의 판타지스타',
#   'star_score': 7.9,
#   'liked': None,
#   'author': '서핑보이',
#   'publisher': '제이플러스',
#   'age_rating': '전체 이용가',
#   'sObjectId': '499325_0',
#   'comment_list': [{'contents': '지금 주인공의 문제점은 딱 하나 피지컬 밖에 없지 않나? 그 중에서도 체력이 제일 문제일 듯 한데 그럼 왜 발롱도르 9번 받은 괴수가 초딩 축구에서 저러고 있는지 의문이 남네.고딩 축구까진 중미 자리에서 다 뚫고 3골 정도 넣은 다음에 수비만 해도 전승 할 거 같은데 이건 무슨 전개지..?',
#     'sympathyCount': 14,
#     'antipathyCount': 0},
#    {'contents': '요즘 회귀는 트럭이나 사고도 필요 없어. 술먹고 자고 일어나도 자동 회귀 되는 애들도 많더라구 ㅋ',
#     'sympathyCount': 13,
#     'antipathyCount': 0}]},
#  '9197875': {'title': '로또부터 장군까지',
#   'star_score': 8.9,
#   'liked': 7,
#   'author': '게르만',
#   'publisher': '로크미디어',
#   'age_rating': '전체 이용가',
#   'sObjectId': '490789_0',
#   'comment_list': [{'contents': '시바 조기튀김은 아니잖아요 작가님...',
#     'sympathyCount': 49,
#     'antipathyCount': 0},
#    {'contents': '암진단후 수술한지 6개월된 암 환자입니다.난 대장암 4기+@ 라..말기랑 약간 겹쳐 있는 상태입니다. 췌장암 1기 정도면 항암치료나 방사선 치료 아마 없을듯 합니다. 표적 치료라는건데.. 암은 수술많이 살길에 대한 답이라 들었습니다.. 항암치료 먼저 합니다.. 라는 말은 살 가망이 낮다는 말이라 하기에 내용상 췌장암이라 나하고는 다른병이지만.. 가슴이 섬뜩해서 몇자 적어봅니다.암 이란 진단을 받았다면.. 빠른 수술이 생명에 도움이 됩니다. ㅠㅠ',
#     'sympathyCount': 41,
#     'antipathyCount': 1},
#    {'contents': '백종원씨가 젊어보일때가 있다구요?거짓말하지 말고 대학때 사진부터 찾아봐요 ㅋㅋㅋ',
#     'sympathyCount': 35,
#     'antipathyCount': 0},
#    {'contents': '저건 죽빵을 날렸어도 인정이지', 'sympathyCount': 22, 'antipathyCount': 0},
#    {'contents': '여성분이신가...이거 군대소설입니다...',
#     'sympathyCount': 20,
#     'antipathyCount': 0},
#    {'contents': '와 나는 왜 이렇게 못 했을까? 돌아갈까?',
#     'sympathyCount': 20,
#     'antipathyCount': 0},
#    {'contents': '그래도 예비군들도 사격은 위험하다는걸 알기에 뻣대거나 사고치는 경우는 거의 없다고 보면 됩니다 소설에서나 등장하죠 현실에선 보기 힘듭니다 아무리 돌아이라도 사격장에선 말 잘들어요',
#     'sympathyCount': 20,
#     'antipathyCount': 0},
#    {'contents': '오렌지는 델몬트지 ㅋ ㅋ', 'sympathyCount': 18, 'antipathyCount': 0},
#    {'contents': 'ㅋㅋㅋㅋ 메소드연기', 'sympathyCount': 18, 'antipathyCount': 0},
#    {'contents': '재밌는 군대소설은 뭣히면 스킵 후 진급이었는데 이 소설은 장기소설로 가면 좋겠습니다',
#     'sympathyCount': 17,
#     'antipathyCount': 0}]},
#  '5896155': {'title': '시한부 천재가 살아남는 법',
#   'star_score': 9.6,
#   'liked': 291,
#   'author': '청시소',
#   'publisher': 'JHS BOOKS',
#   'age_rating': '전체 이용가',
#   'sObjectId': '424012_0',
#   'comment_list': [{'contents': '시리즈 독자분들께 처음으로 인사드립니다. 글쓴이 청시소입니다. 첫 유료 글이 시리즈에 런칭되어 설렜던 게 엊그제 같은데, 어느덧 250화를 넘어섰습니다. 그동안 지켜봐 주셔서 정말, 아주아주 감사할 따름입니다. 이야기가 중요한 파트에 들어섰습니다. 오늘과 내일은 휴재입니다. 근래에 정비가 필요하다는 걸 부쩍 느끼고 있었는데, 차일피일 미루다 미리 공지를 전해 드리지 못해 정말 죄송합니다. 구상에 힘쓰고 글을 다듬어서 월요일에 뵙도록 하겠습니다. 늘 감사히 생각하고 있습니다. 좋은 주말 보내시길 바랍니다.',
#     'sympathyCount': 1023,
#     'antipathyCount': 13},
#    {'contents': '아낌없이 주는 혈염교... 멸마청강수도 만들게 해주고 마라굉혈공도 주고 진법 견식도 하게 해주고 시화무극수 영감도 주고 이번엔 칠사도가 영약까지 갖다바치겠네 이정도면 외가인 입황마가보다 몇배는 도움되는데? 외가보다 쓸모 많은 스토커ㅋㅋㅋㅋ',
#     'sympathyCount': 673,
#     'antipathyCount': 9},
#    {'contents': '페르마:여백이 부족하여 적지 않았다.',
#     'sympathyCount': 626,
#     'antipathyCount': 7},
#    {'contents': '꼭 저렇게 엄마가 죽은게 아이탓이라고 헛소리하는 어른들이 있죠. 저런 인간들 때문에 죄없는 아이들이 고통받죠',
#     'sympathyCount': 612,
#     'antipathyCount': 26},
#    {'contents': '500화가 되도록 함께해 주셔서 감사합니다.여러분 덕분에 저도 정연신의 이야기를 따라갈 수 있었습니다.늦었지만 새해 복 많이 받으시길 바랍니다. 하시는 모든 일들이 잘 풀렸으면 합니다.',
#     'sympathyCount': 595,
#     'antipathyCount': 2},
#    {'contents': '연신: 주변에 유난히도 오만한 사람들이 많아, 근묵자흑을 주의해야겠군숙부: 연신이 너도 크게 다르지 않을듯 싶더구나. .. ',
#     'sympathyCount': 587,
#     'antipathyCount': 5},
#    {'contents': '이젠 자색 위엔 핑크다', 'sympathyCount': 585, 'antipathyCount': 1},
#    {'contents': '지렸다 직접 뺏어서 입 안까지 배달해주네 작가양반 솔직히 말해봐요 칠사도 쟤 적 아니죠 걍 얀데레 아냐?',
#     'sympathyCount': 585,
#     'antipathyCount': 2},
#    {'contents': '역시 같은 ㄱㅈ라고 마진만 편애한거였네',
#     'sympathyCount': 568,
#     'antipathyCount': 6},
#    {'contents': '17세 .. 사정 모르는 놈이 보기엔 살날 존나 많음핏줄.. 패협 마가놈 손자임배분.. 입황성주 직전제자 인맥.. 황태자 사제무력.. 자색 될랑말랑빠른 계산 profit!',
#     'sympathyCount': 560,
#     'antipathyCount': 4}]},
#  '9543502': {'title': '아름다운 톱스타',
#   'star_score': 7.9,
#   'liked': 2,
#   'author': '길밖의새',
#   'publisher': 'HIT',
#   'age_rating': '전체 이용가',
#   'sObjectId': '501800_0',
#   'comment_list': [{'contents': '일러 무서워요 😨 😨 😨 ',
#     'sympathyCount': 10,
#     'antipathyCount': 0}]},
#  '9216527': {'title': '귀촌 첫날 차원문이 생겼다',
#   'star_score': 8.8,
#   'liked': 5,
#   'author': '아피로',
#   'publisher': 'KW북스',
#   'age_rating': '전체 이용가',
#   'sObjectId': '491228_0',
#   'comment_list': [{'contents': '차원문 : 100년만의 변비 끝에 쌌다!!',
#     'sympathyCount': 11,
#     'antipathyCount': 0}]},
#  '9205662': {'title': '내 조선에 세종은 없다',
#   'star_score': 8.9,
#   'liked': 5,
#   'author': '핏콩',
#   'publisher': '제이트리',
#   'age_rating': '전체 이용가',
#   'sObjectId': '490958_0',
#   'comment_list': [{'contents': '제목보고 기겁함',
#     'sympathyCount': 286,
#     'antipathyCount': 1},
#    {'contents': '조선사람들은 쌀밥에 고기국 없어서 못먹었지만 한국사람들은 흰쌀에 고기 작작좀 쳐먹지않으면 비만당뇨고혈압으로 일찍 뒤진다고 의사가 협박해서 못먹음 ',
#     'sympathyCount': 136,
#     'antipathyCount': 0},
#    {'contents': '김종서:80살까지 사직못하는 꿈을꿨어....황희:야 너두??',
#     'sympathyCount': 112,
#     'antipathyCount': 1},
#    {'contents': '황희가 뇌물사범인건 고증입니다. 진짜 청백리는 맹사성이었죠. 그 김종서가 앞에만 서면 바들바들 떨고 그 세종에게 사기까지 치려던 어마무시한 양반이 황희입니다',
#     'sympathyCount': 101,
#     'antipathyCount': 0},
#    {'contents': '황희 : 진정하십시오. 장공주가 조실부모한 까닭에 제대로 배우지 못한 탓도 있을 겁니다.이도 : 주자께선 배움이란 곧 본받는 것이라 하셨는데, 공주는 가정교육을 독학했으니 그럴 수 밖에요!...조선인의 혓바닥에 벌써부터 고춧가루가 전파된 건가? 맵다 매워.',
#     'sympathyCount': 87,
#     'antipathyCount': 0},
#    {'contents': '🚩', 'sympathyCount': 79, 'antipathyCount': 0},
#    {'contents': '조강지처가 문제가 아니라 감히”외척이” “왕이 결정한 일에”토다는게 왕입장에서는 위험한거라서 그러는거임 후궁 대려오면 여인들끼리 견제해야되서 정치자체에 전력을쏟을수 없게되는데 그걸 하지말라고한다? 이방원입장에서는 민씨척족들이”너죽은다음엔 우리가 너 와이프 명분으로 실권쥐고 정치할거임”이러는걸로 들리는거지',
#     'sympathyCount': 68,
#     'antipathyCount': 2},
#    {'contents': '굴라그 ', 'sympathyCount': 68, 'antipathyCount': 0},
#    {'contents': '이성계 일생이야 파란만장 했지만 이 작품에선 말년에 그래도 재밌게 놀다 가네ㅋㅋ',
#     'sympathyCount': 64,
#     'antipathyCount': 0},
#    {'contents': '처음엔 해피엔딩인걸로 주라고ㅋㅋㅋㅋ',
#     'sympathyCount': 61,
#     'antipathyCount': 0}]},
#  '9587854': {'title': '나의 다정한 무뢰한에게 [독점]',
#   'star_score': 8.5,
#   'liked': 10,
#   'author': '만다라',
#   'publisher': '필연매니지먼트',
#   'age_rating': '15세 이용가',
#   'sObjectId': '503316_0',
#   'comment_list': [{'contents': '안녕하세요. 만다라입니다.일년만에 찾아뵙네요. 이번에는 제가 처음으로 다정한 남자주인공을 데려왔습니다. 믿기지 않으실 수도 있지만 그레이는 정말 다정한 남자입니다. (물론 제 주인공들이 다 그렇듯 조금 OOO이긴 합니다만….😏)연재가 처음이라서 걱정이 많네요.두 주인공들의 행복을 위해 최선을 다해 달려보겠습니다.함께 해주세요. 여러분 :)',
#     'sympathyCount': 83,
#     'antipathyCount': 10},
#    {'contents': '여주를 죽일 마음이 없어서 장전한 거처럼 보이지만 실은 안전핀을 안 풀었다든지...발사가 안되게 되어있을거 같네요',
#     'sympathyCount': 45,
#     'antipathyCount': 5},
#    {'contents': '작가님 로판도 흥미진진해요 넘 맛있어요 ㅜ,ㅜ 프롤 진짜 내 취향',
#     'sympathyCount': 37,
#     'antipathyCount': 8},
#    {'contents': '아아 어쩌려고 완결작인줄 알고 여기까지 단숨에 질러버렸을까…작가님 빨리 다음편 주세요ㅠ',
#     'sympathyCount': 27,
#     'antipathyCount': 6},
#    {'contents': '아개읏기다 둘이비밀연인인데 너무 비밀이라 아델도 모름 ㅋㅋ',
#     'sympathyCount': 25,
#     'antipathyCount': 5},
#    {'contents': '이번 편 너무 좋아요. 아슬아슬하니',
#     'sympathyCount': 24,
#     'antipathyCount': 6},
#    {'contents': '흐린글씨 눈이 너무 아파요.ㅠ 조금만 진하게 부탁드려요',
#     'sympathyCount': 22,
#     'antipathyCount': 0},
#    {'contents': '도르안 진짜 꾸준히 캐릭터 명쾌 촐싹 ㅋㅋ',
#     'sympathyCount': 22,
#     'antipathyCount': 4},
#    {'contents': '난 매력 쩌는데 ㅎ', 'sympathyCount': 21, 'antipathyCount': 5},
#    {'contents': '로판인데 진짜 대사같은건 그냥 현대로맨스 같아요 ^^ 재미는 있는데 읭?하게 되네요',
#     'sympathyCount': 21,
#     'antipathyCount': 3}]},
#  '8365155': {'title': '홍등가의 소드마스터',
#   'star_score': 7.3,
#   'liked': 127,
#   'author': '망신창이',
#   'publisher': '문피아',
#   'age_rating': '12세 이용가',
#   'sObjectId': '466209_0',
#   'comment_list': [{'contents': '큰 교훈이군요 시리즈 아이디는 절대 공유하지 않겠습니다',
#     'sympathyCount': 915,
#     'antipathyCount': 12},
#    {'contents': '??: 이것이 우리 제국이 숨기고 있는 힘이다. 제국도 알지 못 하지.',
#     'sympathyCount': 687,
#     'antipathyCount': 9},
#    {'contents': '그와중에 그럴싸한 사무실의 책상도 잘라먹었네ㅋㅋㅋ',
#     'sympathyCount': 653,
#     'antipathyCount': 7},
#    {'contents': '뛰어난 재능을 가진 아이를 본 마법사는 아이를 재료로 생체 아티팩트를 만드려하고,뛰어난 재능을 가진 아이를 본 기사는 위대한 경지에 도달할 아이의 스쳐지나가는 가르침이어도 베풀 수 있다는 것에영광을 느낀다.',
#     'sympathyCount': 635,
#     'antipathyCount': 8},
#    {'contents': '다른 소설은 모르겠는데, 이 소설은 증명시켜줄것 같다',
#     'sympathyCount': 616,
#     'antipathyCount': 9},
#    {'contents': '시리즈 쉑들 이작품 수입한 이유가 이번화 때문인것 같은데',
#     'sympathyCount': 605,
#     'antipathyCount': 5},
#    {'contents': '고아수집가에서 고아메이커로 진화했네ㅋㅋㅋㅋㅋ',
#     'sympathyCount': 589,
#     'antipathyCount': 6},
#    {'contents': '리엑션 장인 로필렌이 이 소식을 들으면 그런 역사적인 순간에 자기만 없었다며 바로 새롭게 오열 리엑션 들어감ㅋㅋㅋㅋㅋ',
#     'sympathyCount': 580,
#     'antipathyCount': 5},
#    {'contents': '훌륭한 대학원생의 자질을 발견한 교수님..',
#     'sympathyCount': 579,
#     'antipathyCount': 5},
#    {'contents': 'A: 팀장님, 막내가 그랜저 타고 왔습니다팀장: 막내가 그랜저 타는게 뭐 어때서? 신경 꺼 꼰대도 아니고A: 각그랜저인데요?팀장: 뭐? 야 나가보자 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#     'sympathyCount': 570,
#     'antipathyCount': 3}]},
#  '4153395': {'title': '공작님, 회개해주세요!',
#   'star_score': 9.2,
#   'liked': 59,
#   'author': '별볆볆별명',
#   'publisher': '글고운',
#   'age_rating': '전체 이용가',
#   'sObjectId': '361308_0',
#   'comment_list': [{'contents': '역대급 명대사 ㅋㅋㅋ "니가 우리 가족에 대해 뭘알아!!".. ㅋㅋㅋㅋ 댓글 안달수없었음.. 그렇지 남의 가족을 니들이 어떻게 알아 ㅋㅋㅋ',
#     'sympathyCount': 422,
#     'antipathyCount': 4},
#    {'contents': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ완벽주의 상사에게 내 땡땡이가 들킨 건에 대하여',
#     'sympathyCount': 397,
#     'antipathyCount': 6},
#    {'contents': '그러니까... 저 서스펜스가 말랑뽀쟉 냥냥이처럼 된다 이거죠...? 이 소설은 힐링물이고...? 퍽이나 믿겠다. ...아냐 믿어봐야지. 지키기는 무슨 공격만 할 듯이 사나웠던 한이가 순하게 웃거나 지키려고 하고 금방이라도 독자 죽일 것 같던 중혁이가 동료가 된 것처럼... 가능성 있어... 응...',
#     'sympathyCount': 243,
#     'antipathyCount': 4},
#    {'contents': '자기한테 계속 썼네... 어릴때부터 감정적으로 힘들거나 하면 신성력으로 안정시킨거구나',
#     'sympathyCount': 241,
#     'antipathyCount': 1},
#    {'contents': '크흡ㅋㅋ들킨거?ㅋㅋ 이래서 눈치빠른 상사는 힘들다니까ㅋ',
#     'sympathyCount': 222,
#     'antipathyCount': 2},
#    {'contents': '책 줄거리 다 알려주네요 길다 길어...그런데 성검의 주인 책으로 읽었으면 대게 재미없었을 거 같아요. 성검 주인 주인공 진실도 모른채 뻘짓하며 돌아다니다가 적들에게 놀아나 친구랑 싸우고, 친구 살려둬서 큰적되고 마왕 1초 강림. 보스 죽였는데 세상은 이미 풍비박산 완전 고구만데...',
#     'sympathyCount': 210,
#     'antipathyCount': 0},
#    {'contents': '나 저 상황이면 벌써 창문열고 기차에서 뛰어내렸다',
#     'sympathyCount': 201,
#     'antipathyCount': 0},
#    {'contents': '...? 뭔진몰라도 그거 아니에요ㅋㅋㅋ',
#     'sympathyCount': 195,
#     'antipathyCount': 2},
#    {'contents': '한스 가정폭력 방조가맞지뭐.. 근데 시온ㅋㅋㅋㅋㅋ스콘 위아래라니 방심하다 터졌다ㅋㅋ',
#     'sympathyCount': 190,
#     'antipathyCount': 0},
#    {'contents': '주인공 아무말대잔치ㅋㅋㅋㅋㅋㅋ 역사와 전통이 있는 개판ㅋㅋㅋㅋㅋㅋㅋ',
#     'sympathyCount': 188,
#     'antipathyCount': 1}]},
#  '9543503': {'title': '아름다운 톱가수',
#   'star_score': 3.7,
#   'liked': 2,
#   'author': '길밖의새',
#   'publisher': 'HIT',
#   'age_rating': '전체 이용가',
#   'sObjectId': '501801_0',
#   'comment_list': [{'contents': '아 그래서 이번편 제목이 저렇구나 ㅋㅋ와세다 ㄲㅓ ㅈㅖ',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '그래 넌 찬익이한테 고마워해야해 ', 'sympathyCount': 0, 'antipathyCount': 0},
#    {'contents': '주변에 넘끌려다니는거 같아 ㅠㅠ ', 'sympathyCount': 0, 'antipathyCount': 0},
#    {'contents': '펍 아 그냥 가라 에궁 왜그리 진상이니',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '잘가 펍 ', 'sympathyCount': 1, 'antipathyCount': 0},
#    {'contents': '야 만든다고 했지 준다고 안했잔아 주지마저런 싹퉁바가지들을 봤나 ',
#     'sympathyCount': 1,
#     'antipathyCount': 0},
#    {'contents': '역시 앵무는 꼭 있어야하네 ', 'sympathyCount': 1, 'antipathyCount': 0},
#    {'contents': '아베 잘가 ㅋㅋ 에구 바보', 'sympathyCount': 1, 'antipathyCount': 0},
#    {'contents': '와세다 인지 짱난다', 'sympathyCount': 1, 'antipathyCount': 0},
#    {'contents': '멋지네 ', 'sympathyCount': 0, 'antipathyCount': 0}]},
#  '9251475': {'title': '재벌집 만렙 아들',
#   'star_score': 8.9,
#   'liked': 20,
#   'author': '오소록',
#   'publisher': '제이트리',
#   'age_rating': '전체 이용가',
#   'sObjectId': '492380_0',
#   'comment_list': [{'contents': '장군 국적이 알고보니 왜국이었나 ㅋㅋㅋㅋㅋ',
#     'sympathyCount': 116,
#     'antipathyCount': 2},
#    {'contents': '아이고 ㅋㅋㅋㅋ 마포구 중동 ㅋㅋㅋㅋ',
#     'sympathyCount': 81,
#     'antipathyCount': 0},
#    {'contents': '저시대에는 저나이대의 아이에게 담배. 술. 복권 같은 거 심부름이 가능했던 시절이기에 파시는 분도 그냥 줍니다.',
#     'sympathyCount': 76,
#     'antipathyCount': 0},
#    {'contents': '읽으면서 빵 터졌네ㅋㅋㅋㅋ계약서가 x으로 보이시나 ㅋㅋㅋㅋ',
#     'sympathyCount': 46,
#     'antipathyCount': 1},
#    {'contents': '나도 초중고 때까지 입가심으로 은단을 먹었음.할머니가 나눠주셔서 먹기 시작했는데, 입에 맞아서 거의 중독이었음. 그땐 동네수퍼나 구멍가게에서도 안약병 비슷한 데 넣어 팔았는데, 먹다보니 향이 약해서 약국에서 고려은단 사먹음. 고등학교 땐 하루에 한통씩 먹었는데... 국민학교 때 작은 거 한통에 백원인가 하던게 나중엔 수십배 올라서 대학교 들어가면서 끊음. 대신에 민트랑 차에 빠짐.',
#     'sympathyCount': 46,
#     'antipathyCount': 1},
#    {'contents': '작가님~이 당시에는 구의원 시의원 없습니다... 구의원 시의원은 김영삼때 지방자치제가 도입되면서 시작되었거든요',
#     'sympathyCount': 36,
#     'antipathyCount': 3},
#    {'contents': '뭐 어떰? 어차피 이런소설 비현실적인 요소 감안하구 보는거구만 난 개꿀잼 ㅋㅋ현실성 따지려면 이런류 앱소설 보면 안되는거지',
#     'sympathyCount': 35,
#     'antipathyCount': 2},
#    {'contents': '분당...판교...수서...19만...진도준이냐',
#     'sympathyCount': 30,
#     'antipathyCount': 2},
#    {'contents': '전생이 김충선 ??임진왜란때 귀화한 왜구출신 장수 김충선이면 인정..',
#     'sympathyCount': 27,
#     'antipathyCount': 1},
#    {'contents': '엄마가 모자란게 아니고 70년대부터 80년대 90년대에는 사람들이 다 순수했다 이웃간에 정도 있었고 진짜 살기 좋았다 ',
#     'sympathyCount': 25,
#     'antipathyCount': 0}]},
#  '9518956': {'title': '천재 귀환자의 힐링카페',
#   'star_score': 8.6,
#   'liked': 3,
#   'author': '호오르혜',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '501043_0',
#   'comment_list': [{'contents': '아 진짜....1년 뒤 일어난 거 진짜 생각보다 많이 신경 쓰이네요? 아버지가 저렇게 다정한데 어떻게 애가 일어나서 놀라고 병원부터 가자는 소릴 안 하시는지...아님 제가 그런 얘길했는데 도현이가 거부했다는 걸 못 봤나요....?',
#     'sympathyCount': 30,
#     'antipathyCount': 1},
#    {'contents': '1년동안 누워있던 아들이 창고정리하고 가게 준비 도운게 철든것 같아서 기분 이상한거로 끝날 일이냐고ㅋㅋ 뭔가 억지 힐링을 강제로 구겨서 주입하려는 느낌?',
#     'sympathyCount': 17,
#     'antipathyCount': 1},
#    {'contents': '1년을 누워있었으면 병원에 가야하지 않나요?',
#     'sympathyCount': 16,
#     'antipathyCount': 4},
#    {'contents': '스킬이라면서 치유 마법은 왜 나오나요 애초에 스킬이라는 단어 자체가 어색합니다 그리고 아버지 반응이 겨우 저런거도 이해가 안가네요 무슨 1년 여행 다녀온거도 아니고 .. 가망없이 누워있다가 저렇게 일어나면 가게 문 닫고 바로 119 부르던가 병원을 데려가는게 정상 아닌가요 현실성이 너무 부족한거 같습니다',
#     'sympathyCount': 11,
#     'antipathyCount': 2},
#    {'contents': '수많은 판타지 웹소설에서 고양이 사료 먹는 드래곤 첨일세. ',
#     'sympathyCount': 10,
#     'antipathyCount': 0}]},
#  '9174710': {'title': '재벌집 천재 감독',
#   'star_score': 8.6,
#   'liked': 34,
#   'author': '산경(山景)',
#   'publisher': 'JHS BOOKS',
#   'age_rating': '전체 이용가',
#   'sObjectId': '490330_0',
#   'comment_list': [{'contents': '달동네 1화 선발대들 평이50화까지 정말 재밌는데 50화부턴 소설이 대본집으로 변해서 대본 지문 대사 디렉팅으로 10화 뚝딱 날라간다는 평이 많습니다 다른 선발대들도 대본으로 분량채우는 거에 관련해 비판이 꽤 있네요 초반부는 재밌다고 합니다 저는 200화쯤 나오면 선발대 여론보고 구울예정입니다',
#     'sympathyCount': 194,
#     'antipathyCount': 0},
#    {'contents': '무료부분만 볼만하다 급격히 무너짐 자기 작품인 재벌집 막내아들 성공했다고 어중간하게 연예계로 비틀어서 쓴거 같은데 최악임',
#     'sympathyCount': 160,
#     'antipathyCount': 6},
#    {'contents': '아니 드라마대사로 몇화를 쓰는겁니까 안읽혀집니다 구매한거 그냥 다넘기는중입니다 흐름만 끊기고 ',
#     'sympathyCount': 130,
#     'antipathyCount': 14},
#    {'contents': '아 뭔소리지 했는데 대본으로 분량먹는다는 댓글이 이해가 가네.... 여기부터 시작인가...',
#     'sympathyCount': 120,
#     'antipathyCount': 2},
#    {'contents': '소설 내용이랑 흐름과 관계없는 대본 지문이 너무 많은것 같네요, 무료라서 소설속 드라마 보는 느낌으로 읽을수는 있는데 100원씩 내면서 보기에는 조금 힘들겠어요.드라마 작가에 도전하기 전 에피소드 대본 연습 하시려는 느낌이 들고, 에피소드 대본 습작을 돈내고 볼 수 는 없어서,하루에 한편씩 무료일때 까지만 즐겨보아야겟어요.',
#     'sympathyCount': 84,
#     'antipathyCount': 1},
#    {'contents': '작품 속에 작품은주인공의 삶과 밀접한 관련이 있을 때 흡입력이 살아납니다.작품을 하면서 깨달음을 얻거나 작품 속 상황이 주인공 삶과 닮아 있을 때 특히 그렇습니다.작가님은 탈출과 콜렉션을 등장시켰을 때 철저히 주인공 능력을 전개하는 요소로 사용했습니다. 저도 그게 좋았구요꾼은 어떤가요? 이번화가 다수의 독자들을 만족시킬 수 있을거라고 확신하시나요?',
#     'sympathyCount': 83,
#     'antipathyCount': 5},
#    {'contents': '보기도 짜증나는 로멘스를 욱여넣은 jtbc를 까는 것인가생각보다 로멘스가 적어서 실망한 작가의 투영인가...',
#     'sympathyCount': 77,
#     'antipathyCount': 0},
#    {'contents': '난 지금까지 메인스토리랑 세 개의 대본 중에 메인스토리가 제일 좋은데 대본은 왜 자꾸 넣는 건지,, 대본도 재미는 있는데 제 취향이 아니거든여... 전 현판을 좋아해서 웹소설을 보는데 왜 조폭 영화 대본을 보여주시려는 건지 모르겠습니다. 다시 말하지만 대본도 재밌어요. 근데 제가 기대한 내용이 아니라는 거죠. 제가 선호하지 않는 웹소설이라는 뜻입니다. 아무리 로맨스 웹소설이 재밌다고 해도 그건 잘 안 보는 것처럼요. 안그래도 좋아하는 소재에 직업물에 제가 좋아할만한 건 다 들어갔는데 조폭물은 영화도 잘 안 본다고요... 이래서 자꾸 사람들 평이 갈리는 듯. ',
#     'sympathyCount': 66,
#     'antipathyCount': 6},
#    {'contents': '원작 작가님 드라마 논의 단계부터 많이 화나셨나봄.. 이리 큰그림을 그리고 계셨다니',
#     'sympathyCount': 57,
#     'antipathyCount': 1},
#    {'contents': '작가님 그 희귀한 여성 독자가 접니다. 드라마 제작 나오기 전에 다 읽었어요. 산경 작가님 재벌집 막내아들은 현판 파는 사람들한테 유명합니다. 너무 재밌어요. 더 주세요. ',
#     'sympathyCount': 57,
#     'antipathyCount': 6}]},
#  '9319558': {'title': '숨만 쉬어도 무공이 생겨',
#   'star_score': 8.3,
#   'liked': 3,
#   'author': '정주(丁柱)',
#   'publisher': '라온E&M',
#   'age_rating': '전체 이용가',
#   'sObjectId': '494576_0',
#   'comment_list': [{'contents': '저가요. 어제 댓글 쓴 대로오늘 2편 예약을 진짜 할라고 했는데요.한 천 자 정도 부족해서 말이죠..1편밖에 못 올립니다.일단 내일은 당연히 올라오고, 2편 예약 할 수 있도록 최선 다하겠습니다.약속을 남발했다가 못 지키면 멘탈이 터지는 개복치 멘탈인 관계로최선을 다하지만, 확답은 하지 않겠습니다.어제도 분명 되는 줄 알았는데 ㅠㅠ',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '어제 본가에 갔다왔더니 근육통으로 내일 2회올리겠습니다.유통 마감 시간에 맞출 수가 없네요...내일 2개 나갑니다! 미리 예고 합니다!',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '와 식신으로 이미지 궅혀지는건가!? 나쁘지 않아! 너무 좋아요! ㅎㅎ 최신편부터 1화까지 다시 정주행 했는데 너무 좋네요 작가님 다음 화도 ㅎ하이팅!(댓을 잘 안달아도 열심 달리고 있습니돠!♪＼(^O^)/(*^_^*)＼(^O^)/ )',
#     'sympathyCount': 1,
#     'antipathyCount': 0},
#    {'contents': '오호 공영두펫이 저리 된거였군요? ',
#     'sympathyCount': 1,
#     'antipathyCount': 0},
#    {'contents': '아으.. 고민이다 지를까.. 아니면 나중의 기쁨을 위해 중단..? 끙.. 몰랏 지른닷! ',
#     'sympathyCount': 1,
#     'antipathyCount': 0},
#    {'contents': '꺅 ㅎㄷㄷ? 이제부터 호러인가!?', 'sympathyCount': 1, 'antipathyCount': 0},
#    {'contents': '어우 속이 다 시원하네 역시 참았다 보는게 꿀맛이구로 기달려서 보는게 지옥이지만.. 재밌습니돠!!',
#     'sympathyCount': 1,
#     'antipathyCount': 0},
#    {'contents': '시간 내 마감 실패로 토요일로,+ 노동절 정상영업 합니다',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '몸살로하루만 더 쉬겠습니다.', 'sympathyCount': 0, 'antipathyCount': 0},
#    {'contents': '두통으로 하루만 더 쉬겠습니다.',
#     'sympathyCount': 0,
#     'antipathyCount': 0}]},
#  '9553143': {'title': '이탈리아에서 살아남기',
#   'star_score': 8.0,
#   'liked': None,
#   'author': '포렴',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '502090_0',
#   'comment_list': [{'contents': '이거 문체가 담담해서 깨닫기 힘든데 동로마제국 이탈리아에서 부활 너무 웃김',
#     'sympathyCount': 19,
#     'antipathyCount': 2}]},
#  '9509566': {'title': '남주의 애인을 꼬셔버렸습니다 [독점]',
#   'star_score': 8.4,
#   'liked': 7,
#   'author': '헤샤',
#   'publisher': '해피북스투유',
#   'age_rating': '15세 이용가',
#   'sObjectId': '500779_0',
#   'comment_list': [{'contents': '지금의 여주는 영혼이 바뀌었으니 독먹인 본인이 아니고, 뭣보다 꽤 어릴때 같은데 재물이 많은것도 고위귀족인 것도 아닌 어린 여자애가 마법사한테 영향을 끼칠만한 독을 어디어 구해서 먹일생각을 했을까 싶은데 말이죠. 진짜 마리아를 누가 이용한건 아닐까. 분노가 향할 방향이 잘못 됬든지 제일 만만하니 희생양이 됬든지..? 당장 시계도 못사는 집에서, 그 전에는 좀 더 재산이 있긴 했겠지만 그래도 고위귀족도 아니고 나이가 어린애가 부모님도 모르게 용의주도하게 마법사에게 통하는 독을 구한다는것 부터가 말이 안되는데....거기다 원래 마리아의 성격은 소심 심약 자체인것 같으니 더 앞뒤가 안맞는 느낌인데 말이죠..,',
#     'sympathyCount': 49,
#     'antipathyCount': 3},
#    {'contents': '안녕하세요 헤샤입니다. 네이버 독자님들께 처음으로 인사드리게 되어 정말 긴장되고 설레는데요! 여러분들이 재밌게 보고 즐거워하셨으면 좋겠습니다. 감사드리고 사랑합니다!! ',
#     'sympathyCount': 48,
#     'antipathyCount': 0},
#    {'contents': '아니 애당초 왜 아무도 이상하다고 생각을 안한건데? 어리고 재산도 권력도 없는 가난한 귀족집 영애가 무슨 수로 그렇게 대단하고 귀한 독초를 찾아 사는데?',
#     'sympathyCount': 42,
#     'antipathyCount': 0},
#    {'contents': '겁나 소름끼침 와 나는 일도 맘이 없는데 아름답다는 이유로 성희롱 당하고 구애 당하구 이성애자인데 동성들한테 성적 폭력을 당하면 기분 진짜 엿같아기분이 나도 이렇게 드러운데 ',
#     'sympathyCount': 38,
#     'antipathyCount': 0},
#    {'contents': '....너무기가막혀서 말이 안나오네. 저거...어린 마리아를 이용해 독 먹인게 사실 저놈 아닐까...',
#     'sympathyCount': 33,
#     'antipathyCount': 0},
#    {'contents': "여주 항상 싸가지 운운하는데 정작 본인이 제일 싸가지 없다는건 모르는듯..본인이 사고친거에 피해본 상대가 화내면 '아니, 내가 잘못하긴 했는데 솔직히 저렇게 화낼 정도는 아니지 않나? 예민미쩌네; 개싸가지' 이러면서 본인이 잘못한걸 상대방의 기준이 아니라 본인의 기준으로 멋대로 판단하며 씹어대고 본인 기분 조금만 어긋나면 본인은 아무 잘못 없는 선량한 피해자로 생각하고 상대는 악당 취급하질 않나 이걸 내로남불이라고 해야하나 자기 합리화라고 해야하나..지금도 이안이 위험 감수하고 도와준건데 그런 사람을 상대로 속으로 똥강아지 취급에 본인이 사고친거 뒷수습 다 해주고 치료까지 해주고나서 위험하다고 주의 주는걸 쓸데없는 잔소리 취급하질 않나..그냥 클로드가 상대적으로 더 쓰레기라 가려져서 그렇지 여주도 하는 꼴 보면 만만찮음.. 완전체 같은 느낌이라고 해야하나..정확히 내가 싫어하는 타입의 인간이라 그냥 여주 인성은 잘라먹고 스토리만 본다 생각하고 흐린눈으로 보는 중임..",
#     'sympathyCount': 25,
#     'antipathyCount': 2},
#    {'contents': "여기저기 조사들이 빠지거나 맞지 않는게 쓰이기 일쑤고 중간중간 아작낸다던지 *랄 옘병 한다는 등의 어투가 전체적으로 작품 분위기를 가볍게 만드네요.이번에 나온 신작 3개 중에서 소재가 제일 재밌어 보여서 읽는데 .. 음.. 뭐랄까 약간 'ㄹㅇ ㅋㅋ~ 뚝배기를~' 같은 느낌의 로판보다는 현판에 어울릴 법한 가벼운 언행들로 이루어진 구성에 더해 계속해서 빠지거나 맞지 않는 조사들의 쓰임, 초반인데도 애매하다고 느껴지는 몇몇 개연성의 부재 같은 것들이 전체적으로 작품 퀄리티가 떨어진다는 느낌을 주네요.어지간하면 조사 관련 오타가 나도 사람인데 실수 할 수 있지 하면서 그냥 보는 편인데 한 편에 한 두개도 아니고 수두룩하게 나오니 보다가도 자꾸 집중이 흐트러지고, 여주는 양아치 마냥 언행이 가벼워 전체적인 몰입도도 떨어지고.무엇보다 여주의 인성, 캐릭터성, 성격이 호감형이냐 하면 딱히 그것도 아니고.단순히 최근 제가 봐오던 소설들과는 결이 달라서 그런가 싶어 조금 더 봐야 알겠네요.",
#     'sympathyCount': 22,
#     'antipathyCount': 1},
#    {'contents': '현 공작은 데릴사위주제에오만함의 극치네. 제정신인가?',
#     'sympathyCount': 21,
#     'antipathyCount': 0},
#    {'contents': '....(욕)(심한욕)(매우심한욕)저딴게 원작 남주라고?',
#     'sympathyCount': 20,
#     'antipathyCount': 0},
#    {'contents': '소식듣고 왔어요!! 꺄아악!!! 근데 표지에 여주가 남주 멱살 잡으면서 웃고 있네요!ㅋㅋㅋㅋ 너무이뻐(?)',
#     'sympathyCount': 19,
#     'antipathyCount': 0}]},
#  '9576221': {'title': '말단 병사가 2회차를 숨김',
#   'star_score': 8.5,
#   'liked': 3,
#   'author': '2차자아',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '502810_0',
#   'comment_list': [{'contents': '소설 주인공이야 작가버프로 개연성 파괴하고 승승장구하지만 우리가 그러면? 그 유명한 형님 이새끼 웃는데요? 앤딩임...',
#     'sympathyCount': 20,
#     'antipathyCount': 0},
#    {'contents': '직장인하던사람이 10년만에 기사되고 오러깨우친거면 쌉재능러 같은데',
#     'sympathyCount': 16,
#     'antipathyCount': 0}]},
#  '8898758': {'title': '용병이 되었다 [독점]',
#   'star_score': 6.1,
#   'liked': 1,
#   'author': '화산뿔멧돼지',
#   'publisher': '알에스미디어',
#   'age_rating': '전체 이용가',
#   'sObjectId': '483841_0',
#   'comment_list': [{'contents': '현재 나와있는 18화까지 보고 왜 평점이 낮은지 확실히 알게됨이 소설만의 고유 설정, 단어, 그와 관련된 사건들이 많음그걸 알아갈 시간을 안주고 짧은 지면에 다 때려넣음독자는 모르는게 나오면 그걸 다 외우는게 아니라중요하게 설명되는걸 우선 기억하고 나머지는 반복해서 보는걸로 머리속에 넣는건데마대자루에서 쓰레기 버리듯이 우르르 쏟아내면 뭐를 기억해야하나다 기억하고 넘어가야하나 고민할만큼의 재미도 없음작가가 머리속으로 그리는 멋있음이 뭐지는 알겠는데표현방법이 너무 후짐작가도 목표로 하는 재미있게 본 판무 있을텐데그 소설에서 이런식으로 설정을, 떡밥을 풀어나갔는지 생각해보길',
#     'sympathyCount': 43,
#     'antipathyCount': 1},
#    {'contents': '반이 투레질을 했다고요..? 투레질은 말이 하는 거잖아요..',
#     'sympathyCount': 13,
#     'antipathyCount': 1}]},
#  '9599215': {'title': '아포칼립스에 집을 숨김',
#   'star_score': 9.2,
#   'liked': 26,
#   'author': '로드워리어',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '503591_0',
#   'comment_list': [{'contents': '🔥전설의 아포칼립스 명작 드디어 시리즈 상륙!🔥문피아 무료1위 유료1위 연속 알박, 독자 추천글 역대급 러쉬의 화제의 대작!⭐ 1~11화 : 1화 1에피로 등장인물, 세계관 소개 ⭐ 12화 이후 : 서서히 주인공 중심으로 메인스토리 시작🔥독창적 스토리, 입체적 캐릭터, 비장함, 감동, 유머까지 다 갖춘 아포칼립스 필독서! 해피엔딩 복선 있음! 안보면 인생손해! 🔥개인적인 추천 에피소드 : 캣맘, 재벌, 골드, 빛이 된 남자, 변신, 불멸, 메시아, 거목, 판결 (114화 연재 기준)*️⃣ 이 작가님의 다른 추천 작품 : 주인공이 자비를 숨김, 주인공이 힘을 숨김 (이분이 숨김제목 원조! 재밌으면 같이 읽어보세요!^.^)',
#     'sympathyCount': 362,
#     'antipathyCount': 63},
#    {'contents': '뭔가 일부러 밉상소리 하며 몸을 뺀거 같은데? 와서 보고 나니 이건 혼자만의 쉘터라는걸 느낀건가?',
#     'sympathyCount': 210,
#     'antipathyCount': 7},
#    {'contents': '2023년 문피아 최고의 작품',
#     'sympathyCount': 140,
#     'antipathyCount': 33},
#    {'contents': '배가 부른 게 아니고 방공호 보고 들어와도 문제 생길 수밖에 없는 거 느낀 듯 그래서 일부로 싫은 소리 하면서 못 산다고 한 거 같고 죽지만 않으면 좋겠네..',
#     'sympathyCount': 135,
#     'antipathyCount': 2},
#    {'contents': '계산이 빠른거지... 어떻게든 비비고 들어와도 탈이 날 수 밖에 없다는걸.가족끼리 있어도 프라이버시 없으면 문제가 생기는데...사실상 인간사냥꾼이랑 비슷하게 사회부적응자인 쥔공이랑 같이 있으면 둘중에 하나는 마빡을 도끼 수납장으로 쓰게 될거임.',
#     'sympathyCount': 120,
#     'antipathyCount': 4},
#    {'contents': '헐 죽으라고 민물에 넣은거였어ㅜㅜ',
#     'sympathyCount': 116,
#     'antipathyCount': 3},
#    {'contents': '인간 사냥꾼 자꾸 보니까 정들 것 같음ㅋㅋㅋㅋㅋ ',
#     'sympathyCount': 115,
#     'antipathyCount': 5},
#    {'contents': '질질 안 끌고 분랑늘리기 장난없이 짧은 회차속에 넣을거 다 넣으니 좋네',
#     'sympathyCount': 110,
#     'antipathyCount': 0},
#    {'contents': '이번 편은 꽤나 슬프다', 'sympathyCount': 102, 'antipathyCount': 7},
#    {'contents': '이미 자신이 죽이려 했기 때문에 광분한거네 ',
#     'sympathyCount': 97,
#     'antipathyCount': 1}]},
#  '9360005': {'title': '파천옥녀제왕도',
#   'star_score': 8.9,
#   'liked': 1,
#   'author': '필걸',
#   'publisher': 'JC미디어',
#   'age_rating': '15세 이용가',
#   'sObjectId': '496163_0',
#   'comment_list': [{'contents': '별점이 점점 올라가네... 함 읽어볼까?',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '그림은 남매인데..(아직 읽기전)',
#     'sympathyCount': 1,
#     'antipathyCount': 1}]},
#  '9633528': {'title': '재벌녀의 두 번째 남편',
#   'star_score': 7.4,
#   'liked': 7,
#   'author': '악중선',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '504456_0',
#   'comment_list': [{'contents': '전아내 예기좀 그만하면 안됩니까?글쓴이마음도 이해는간다만...여긴소설이잖아요...일기장이아닙니다..',
#     'sympathyCount': 38,
#     'antipathyCount': 9},
#    {'contents': '문체나 문장이 거친데 묘하게 현장감이 있음. ',
#     'sympathyCount': 10,
#     'antipathyCount': 1}]}}

# %%
with open(f'product_{start}_{end}.txt', 'wb') as f:
    pickle.dump(product, f)

# %%
with open(f'product_{start}_{end}.txt', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'9440917': {'title': '히든 피스로 전설 기사',
#   'star_score': 8.3,
#   'liked': 1,
#   'author': 'S.Captain',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '498891_0',
#   'comment_list': [{'contents': '주69시간제로 성큼 다가온 이세계 빙의 위험성',
#     'sympathyCount': 132,
#     'antipathyCount': 12},
#    {'contents': '아...유치하네...', 'sympathyCount': 51, 'antipathyCount': 7},
#    {'contents': '짜증나서 댓글 쓰는데 레벨에대한 설정을좀 제대로 해애할꺼같음 처음 검술얻었을때는 실제수준이아니구 육체에대한 강함기준으로 가는것 같더니 점점갈수록 오류가 나더니.이번화에서는 기존 육체강화에 8배인데 레벨 2상승 ? 너무 수치상승이 괴랄했음 뭐 계속 이렇게.올리는게힘들다 설정에 그만큼 강하다라는설정이면 처음 세계관최강자설정이 너무 말도안댐 설정좀 자세히 생각하고 글을써주셨으면 하는바람',
#     'sympathyCount': 24,
#     'antipathyCount': 0},
#    {'contents': '이 책의 제목은 잘못되었다.히든피스로 주인공 강탈. 이게 맞다.',
#     'sympathyCount': 21,
#     'antipathyCount': 0},
#    {'contents': "29화 16%쯤 켈베르트가 과거 회상하는 씬에서'명성 높은 가문의 아들로 태어나 어린 시절부터 가족들의 기대를 한 몸에 받았고, 자신 역시 그 기대에 부응할 만한 모습을 보여주었다.주변 사람 모두가 입이 마르도록 그의 실력과 인품을 칭송했고, 과연 드높은 가문의 명성에 어울리는 인재라는 평이 자자했다.'라고 묘사... 아르민 어린시절이랑 맞지않아 수정이 필요할듯 싶습니다.",
#     'sympathyCount': 19,
#     'antipathyCount': 0},
#    {'contents': '니나는 이제 마네킹되었나', 'sympathyCount': 19, 'antipathyCount': 0},
#    {'contents': '이건 솔직히 개연성이 없어도 너무 없는데? 가끔 머리가 확 도는 성격이긴 하지만 기본적으론 계산에 뛰어나며 용병단에 이득이 되는 쪽으로 움직여왔던 단장이 이미 완벽하게 전쟁을 준비하고 전력도 막강하다는걸 알면서도 왜 남작쪽에 붙었으며.주인공도 가족처럼 지내왔다는 용병단 일원들이 패배할것이 확정된 전장에 참가하겠다는 걸 원작 주인공이 있다는 이유만으로 말리지 않는 것이 무슨 소설에 미친 사이코패스같이 그린건 정말 이해가 안되는데?적어도 주인공은 반대 했는데 어쩔수 없는 상황을 만들어서 개연성을 챙겼어야지.그게 힘든 것도 아니고, 작가가 아닌 내가 지금 잠깐만 생각해봐도 감옥에 붙잡혔을때 명분이라도 챙긴답시고 용병단에 누명씌우고 죽일려던거 단장이 금패를 가진 실력자라는 걸 알고서는 곧 일어날것 같은 전쟁에 억지로 참전 하는걸 조건으로 풀어준다거나 하는 개연성을 집어넣을 수 있었을텐데? 이건 작가의 순수한 역량부족이고 소설 속 개연성의 커다란 오류이다.',
#     'sympathyCount': 17,
#     'antipathyCount': 0},
#    {'contents': '이후에도 그럴지는 모르겠지만"(?)" 이 부호를 너무 남발하여 가볍고 유치한 글처럼 느껴지게 만듭니다.',
#     'sympathyCount': 14,
#     'antipathyCount': 1},
#    {'contents': '이름 언제 불렀어..?', 'sympathyCount': 13, 'antipathyCount': 1},
#    {'contents': '숏소드 8실버 사놓고 자꾸 6실버래..제값주고 8실버에사고 덤으로 전설검 받아온거 아닌가?',
#     'sympathyCount': 13,
#     'antipathyCount': 1}]},
#  '8294718': {'title': '귀환 첫날 아포칼립스가 열렸다',
#   'star_score': 8.5,
#   'liked': 16,
#   'author': '편몽',
#   'publisher': '라온E&M',
#   'age_rating': '전체 이용가',
#   'sObjectId': '464057_0',
#   'comment_list': [{'contents': '설명에 이능력 멀쩡한 상태로 귀환한다더니 이걸 이렇게 사기를 치네. 이능력 하나는 멀쩡한건 맞네',
#     'sympathyCount': 64,
#     'antipathyCount': 5},
#    {'contents': '아니 평화로운 세상이라고 가져온 능력이 오히려 바보 같은 선택같은데?... 아니 아무런 작업없이 강화된 식칼을 팔면 어떻게 되겠음... 바로 어디 범죄조직 끌려가서 마약 강화나 강제로 하거나 국방부 끌려가서 무기 강화 강제로 하고나 51구역에 납치당해서 외계인이랑 싸비싸바하든 강화인간을 만들든 실험이나 당하겠지',
#     'sympathyCount': 51,
#     'antipathyCount': 8},
#    {'contents': '결국 이것도 다운그레이드 구나고구마 들어간다 입 벌려라~',
#     'sympathyCount': 46,
#     'antipathyCount': 5},
#    {'contents': '아포칼립스에서 식량난 오질텐데 하필 대가가 포만감 ㅋㅋ 좃대써!',
#     'sympathyCount': 34,
#     'antipathyCount': 1},
#    {'contents': '국밥은 다 먹게 해줘라...', 'sympathyCount': 34, 'antipathyCount': 1},
#    {'contents': '달피아 아재 짬바 ㅋㅋㅋ', 'sympathyCount': 21, 'antipathyCount': 1},
#    {'contents': '이제 대식이가 지혁아… &lt;&lt;&lt;만 해도 웃기다고 ㅋㅋㅋㅋㅋㅋㅋ',
#     'sympathyCount': 20,
#     'antipathyCount': 1},
#    {'contents': '마지막 부디... 무사하시길 ㅋㅋㅋㅋㅋㅋ 알면 주인공한테 알려줘 ㅋㅋ',
#     'sympathyCount': 18,
#     'antipathyCount': 0},
#    {'contents': '극한상황에 인간 본성 나오는데 저런 인격자는 동료원픽이지',
#     'sympathyCount': 17,
#     'antipathyCount': 0},
#    {'contents': '상상에서도 소심하군 당연히 와락 포옹을 노려야지 ㅋㅋ 고긴데',
#     'sympathyCount': 15,
#     'antipathyCount': 1}]},
#  '9083751': {'title': '마이클 조던 보다 농구 잘함',
#   'star_score': 7.6,
#   'liked': None,
#   'author': '자유수달',
#   'publisher': '라온E&M',
#   'age_rating': '전체 이용가',
#   'sObjectId': '488008_0',
#   'comment_list': [{'contents': '야 너무 돌아왔잖아',
#     'sympathyCount': 13,
#     'antipathyCount': 0}]},
#  '9653969': {'title': '당가암룡',
#   'star_score': 8.8,
#   'liked': 14,
#   'author': '처량한날',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '505218_0',
#   'comment_list': [{'contents': '101화까지 다본 선발대입니다.1. 시리즈기준 9점급 충분합니다.2. 초반 쾌속진행후 외유를 돌며 빌드업하는 이벤트들이 촘촘하고짜임새 있습니다. 조금씩 겹쳐지며 80화부근서 폭발하며 본격적인행보가 나옵니다.특히 그부근 한회차는 역대급 뽕차오르는 서사의폭발이 있습니다.3.80화이후 수신을 끝내고 제가를 하며 치국으로 이어질듯한데다양한 서사가 잘 어우러집니다.큰틀의 이야기와 작은 이야기들이잘 버무러짐4.약간 선협요소가 있으나 정통구무협 스럽고 무공경지 묘사나심득의 체화가 수준있습니다. 강해지는 맛이 있음.5. 다소 불친절한 설정해설은 읽다보면 자연스레 보충되는데초중반 약간 적응안될땐 진입벽이 있습니다.가령 일반무협의 경지상 고수취급 용어가 어기응령이고삼정조화가 초고수급 용어입니다. 작중 삼정조화는 한방파 한명급인걸로 보여지고요.지금 주인공이 어기응령끝자락 삼정조화 목전.6. 캐릭터성 관계성이 어찌보면 복잡 자세하고 어찌보면 좀 뜬금없는 부분이 있음',
#     'sympathyCount': 72,
#     'antipathyCount': 8},
#    {'contents': '와 전개 신선하네요.예상 못했다. 도울줄 알았는데 ㄷㄷ',
#     'sympathyCount': 14,
#     'antipathyCount': 3},
#    {'contents': '친남매간의 불륜을 넘는 사련의 잉태물인데 작가가 하도 반전의 뒤집기에 능해 단정짓기가 애매하네. 지켜봐야 할 듯.',
#     'sympathyCount': 11,
#     'antipathyCount': 3},
#    {'contents': '와.....이런 식의 가화만사성 이루는거야? ',
#     'sympathyCount': 11,
#     'antipathyCount': 3}]},
#  '9455456': {'title': '필드의 판타지스타',
#   'star_score': 7.9,
#   'liked': None,
#   'author': '서핑보이',
#   'publisher': '제이플러스',
#   'age_rating': '전체 이용가',
#   'sObjectId': '499325_0',
#   'comment_list': [{'contents': '지금 주인공의 문제점은 딱 하나 피지컬 밖에 없지 않나? 그 중에서도 체력이 제일 문제일 듯 한데 그럼 왜 발롱도르 9번 받은 괴수가 초딩 축구에서 저러고 있는지 의문이 남네.고딩 축구까진 중미 자리에서 다 뚫고 3골 정도 넣은 다음에 수비만 해도 전승 할 거 같은데 이건 무슨 전개지..?',
#     'sympathyCount': 14,
#     'antipathyCount': 0},
#    {'contents': '요즘 회귀는 트럭이나 사고도 필요 없어. 술먹고 자고 일어나도 자동 회귀 되는 애들도 많더라구 ㅋ',
#     'sympathyCount': 13,
#     'antipathyCount': 0}]},
#  '9197875': {'title': '로또부터 장군까지',
#   'star_score': 8.9,
#   'liked': 7,
#   'author': '게르만',
#   'publisher': '로크미디어',
#   'age_rating': '전체 이용가',
#   'sObjectId': '490789_0',
#   'comment_list': [{'contents': '시바 조기튀김은 아니잖아요 작가님...',
#     'sympathyCount': 49,
#     'antipathyCount': 0},
#    {'contents': '암진단후 수술한지 6개월된 암 환자입니다.난 대장암 4기+@ 라..말기랑 약간 겹쳐 있는 상태입니다. 췌장암 1기 정도면 항암치료나 방사선 치료 아마 없을듯 합니다. 표적 치료라는건데.. 암은 수술많이 살길에 대한 답이라 들었습니다.. 항암치료 먼저 합니다.. 라는 말은 살 가망이 낮다는 말이라 하기에 내용상 췌장암이라 나하고는 다른병이지만.. 가슴이 섬뜩해서 몇자 적어봅니다.암 이란 진단을 받았다면.. 빠른 수술이 생명에 도움이 됩니다. ㅠㅠ',
#     'sympathyCount': 41,
#     'antipathyCount': 1},
#    {'contents': '백종원씨가 젊어보일때가 있다구요?거짓말하지 말고 대학때 사진부터 찾아봐요 ㅋㅋㅋ',
#     'sympathyCount': 35,
#     'antipathyCount': 0},
#    {'contents': '저건 죽빵을 날렸어도 인정이지', 'sympathyCount': 22, 'antipathyCount': 0},
#    {'contents': '여성분이신가...이거 군대소설입니다...',
#     'sympathyCount': 20,
#     'antipathyCount': 0},
#    {'contents': '와 나는 왜 이렇게 못 했을까? 돌아갈까?',
#     'sympathyCount': 20,
#     'antipathyCount': 0},
#    {'contents': '그래도 예비군들도 사격은 위험하다는걸 알기에 뻣대거나 사고치는 경우는 거의 없다고 보면 됩니다 소설에서나 등장하죠 현실에선 보기 힘듭니다 아무리 돌아이라도 사격장에선 말 잘들어요',
#     'sympathyCount': 20,
#     'antipathyCount': 0},
#    {'contents': '오렌지는 델몬트지 ㅋ ㅋ', 'sympathyCount': 18, 'antipathyCount': 0},
#    {'contents': 'ㅋㅋㅋㅋ 메소드연기', 'sympathyCount': 18, 'antipathyCount': 0},
#    {'contents': '재밌는 군대소설은 뭣히면 스킵 후 진급이었는데 이 소설은 장기소설로 가면 좋겠습니다',
#     'sympathyCount': 17,
#     'antipathyCount': 0}]},
#  '5896155': {'title': '시한부 천재가 살아남는 법',
#   'star_score': 9.6,
#   'liked': 291,
#   'author': '청시소',
#   'publisher': 'JHS BOOKS',
#   'age_rating': '전체 이용가',
#   'sObjectId': '424012_0',
#   'comment_list': [{'contents': '시리즈 독자분들께 처음으로 인사드립니다. 글쓴이 청시소입니다. 첫 유료 글이 시리즈에 런칭되어 설렜던 게 엊그제 같은데, 어느덧 250화를 넘어섰습니다. 그동안 지켜봐 주셔서 정말, 아주아주 감사할 따름입니다. 이야기가 중요한 파트에 들어섰습니다. 오늘과 내일은 휴재입니다. 근래에 정비가 필요하다는 걸 부쩍 느끼고 있었는데, 차일피일 미루다 미리 공지를 전해 드리지 못해 정말 죄송합니다. 구상에 힘쓰고 글을 다듬어서 월요일에 뵙도록 하겠습니다. 늘 감사히 생각하고 있습니다. 좋은 주말 보내시길 바랍니다.',
#     'sympathyCount': 1023,
#     'antipathyCount': 13},
#    {'contents': '아낌없이 주는 혈염교... 멸마청강수도 만들게 해주고 마라굉혈공도 주고 진법 견식도 하게 해주고 시화무극수 영감도 주고 이번엔 칠사도가 영약까지 갖다바치겠네 이정도면 외가인 입황마가보다 몇배는 도움되는데? 외가보다 쓸모 많은 스토커ㅋㅋㅋㅋ',
#     'sympathyCount': 673,
#     'antipathyCount': 9},
#    {'contents': '페르마:여백이 부족하여 적지 않았다.',
#     'sympathyCount': 626,
#     'antipathyCount': 7},
#    {'contents': '꼭 저렇게 엄마가 죽은게 아이탓이라고 헛소리하는 어른들이 있죠. 저런 인간들 때문에 죄없는 아이들이 고통받죠',
#     'sympathyCount': 612,
#     'antipathyCount': 26},
#    {'contents': '500화가 되도록 함께해 주셔서 감사합니다.여러분 덕분에 저도 정연신의 이야기를 따라갈 수 있었습니다.늦었지만 새해 복 많이 받으시길 바랍니다. 하시는 모든 일들이 잘 풀렸으면 합니다.',
#     'sympathyCount': 595,
#     'antipathyCount': 2},
#    {'contents': '연신: 주변에 유난히도 오만한 사람들이 많아, 근묵자흑을 주의해야겠군숙부: 연신이 너도 크게 다르지 않을듯 싶더구나. .. ',
#     'sympathyCount': 587,
#     'antipathyCount': 5},
#    {'contents': '이젠 자색 위엔 핑크다', 'sympathyCount': 585, 'antipathyCount': 1},
#    {'contents': '지렸다 직접 뺏어서 입 안까지 배달해주네 작가양반 솔직히 말해봐요 칠사도 쟤 적 아니죠 걍 얀데레 아냐?',
#     'sympathyCount': 585,
#     'antipathyCount': 2},
#    {'contents': '역시 같은 ㄱㅈ라고 마진만 편애한거였네',
#     'sympathyCount': 568,
#     'antipathyCount': 6},
#    {'contents': '17세 .. 사정 모르는 놈이 보기엔 살날 존나 많음핏줄.. 패협 마가놈 손자임배분.. 입황성주 직전제자 인맥.. 황태자 사제무력.. 자색 될랑말랑빠른 계산 profit!',
#     'sympathyCount': 560,
#     'antipathyCount': 4}]},
#  '9543502': {'title': '아름다운 톱스타',
#   'star_score': 7.9,
#   'liked': 2,
#   'author': '길밖의새',
#   'publisher': 'HIT',
#   'age_rating': '전체 이용가',
#   'sObjectId': '501800_0',
#   'comment_list': [{'contents': '일러 무서워요 😨 😨 😨 ',
#     'sympathyCount': 10,
#     'antipathyCount': 0}]},
#  '9216527': {'title': '귀촌 첫날 차원문이 생겼다',
#   'star_score': 8.8,
#   'liked': 5,
#   'author': '아피로',
#   'publisher': 'KW북스',
#   'age_rating': '전체 이용가',
#   'sObjectId': '491228_0',
#   'comment_list': [{'contents': '차원문 : 100년만의 변비 끝에 쌌다!!',
#     'sympathyCount': 11,
#     'antipathyCount': 0}]},
#  '9205662': {'title': '내 조선에 세종은 없다',
#   'star_score': 8.9,
#   'liked': 5,
#   'author': '핏콩',
#   'publisher': '제이트리',
#   'age_rating': '전체 이용가',
#   'sObjectId': '490958_0',
#   'comment_list': [{'contents': '제목보고 기겁함',
#     'sympathyCount': 286,
#     'antipathyCount': 1},
#    {'contents': '조선사람들은 쌀밥에 고기국 없어서 못먹었지만 한국사람들은 흰쌀에 고기 작작좀 쳐먹지않으면 비만당뇨고혈압으로 일찍 뒤진다고 의사가 협박해서 못먹음 ',
#     'sympathyCount': 136,
#     'antipathyCount': 0},
#    {'contents': '김종서:80살까지 사직못하는 꿈을꿨어....황희:야 너두??',
#     'sympathyCount': 112,
#     'antipathyCount': 1},
#    {'contents': '황희가 뇌물사범인건 고증입니다. 진짜 청백리는 맹사성이었죠. 그 김종서가 앞에만 서면 바들바들 떨고 그 세종에게 사기까지 치려던 어마무시한 양반이 황희입니다',
#     'sympathyCount': 101,
#     'antipathyCount': 0},
#    {'contents': '황희 : 진정하십시오. 장공주가 조실부모한 까닭에 제대로 배우지 못한 탓도 있을 겁니다.이도 : 주자께선 배움이란 곧 본받는 것이라 하셨는데, 공주는 가정교육을 독학했으니 그럴 수 밖에요!...조선인의 혓바닥에 벌써부터 고춧가루가 전파된 건가? 맵다 매워.',
#     'sympathyCount': 87,
#     'antipathyCount': 0},
#    {'contents': '🚩', 'sympathyCount': 79, 'antipathyCount': 0},
#    {'contents': '조강지처가 문제가 아니라 감히”외척이” “왕이 결정한 일에”토다는게 왕입장에서는 위험한거라서 그러는거임 후궁 대려오면 여인들끼리 견제해야되서 정치자체에 전력을쏟을수 없게되는데 그걸 하지말라고한다? 이방원입장에서는 민씨척족들이”너죽은다음엔 우리가 너 와이프 명분으로 실권쥐고 정치할거임”이러는걸로 들리는거지',
#     'sympathyCount': 68,
#     'antipathyCount': 2},
#    {'contents': '굴라그 ', 'sympathyCount': 68, 'antipathyCount': 0},
#    {'contents': '이성계 일생이야 파란만장 했지만 이 작품에선 말년에 그래도 재밌게 놀다 가네ㅋㅋ',
#     'sympathyCount': 64,
#     'antipathyCount': 0},
#    {'contents': '처음엔 해피엔딩인걸로 주라고ㅋㅋㅋㅋ',
#     'sympathyCount': 61,
#     'antipathyCount': 0}]},
#  '9587854': {'title': '나의 다정한 무뢰한에게 [독점]',
#   'star_score': 8.5,
#   'liked': 10,
#   'author': '만다라',
#   'publisher': '필연매니지먼트',
#   'age_rating': '15세 이용가',
#   'sObjectId': '503316_0',
#   'comment_list': [{'contents': '안녕하세요. 만다라입니다.일년만에 찾아뵙네요. 이번에는 제가 처음으로 다정한 남자주인공을 데려왔습니다. 믿기지 않으실 수도 있지만 그레이는 정말 다정한 남자입니다. (물론 제 주인공들이 다 그렇듯 조금 OOO이긴 합니다만….😏)연재가 처음이라서 걱정이 많네요.두 주인공들의 행복을 위해 최선을 다해 달려보겠습니다.함께 해주세요. 여러분 :)',
#     'sympathyCount': 83,
#     'antipathyCount': 10},
#    {'contents': '여주를 죽일 마음이 없어서 장전한 거처럼 보이지만 실은 안전핀을 안 풀었다든지...발사가 안되게 되어있을거 같네요',
#     'sympathyCount': 45,
#     'antipathyCount': 5},
#    {'contents': '작가님 로판도 흥미진진해요 넘 맛있어요 ㅜ,ㅜ 프롤 진짜 내 취향',
#     'sympathyCount': 37,
#     'antipathyCount': 8},
#    {'contents': '아아 어쩌려고 완결작인줄 알고 여기까지 단숨에 질러버렸을까…작가님 빨리 다음편 주세요ㅠ',
#     'sympathyCount': 27,
#     'antipathyCount': 6},
#    {'contents': '아개읏기다 둘이비밀연인인데 너무 비밀이라 아델도 모름 ㅋㅋ',
#     'sympathyCount': 25,
#     'antipathyCount': 5},
#    {'contents': '이번 편 너무 좋아요. 아슬아슬하니',
#     'sympathyCount': 24,
#     'antipathyCount': 6},
#    {'contents': '흐린글씨 눈이 너무 아파요.ㅠ 조금만 진하게 부탁드려요',
#     'sympathyCount': 22,
#     'antipathyCount': 0},
#    {'contents': '도르안 진짜 꾸준히 캐릭터 명쾌 촐싹 ㅋㅋ',
#     'sympathyCount': 22,
#     'antipathyCount': 4},
#    {'contents': '난 매력 쩌는데 ㅎ', 'sympathyCount': 21, 'antipathyCount': 5},
#    {'contents': '로판인데 진짜 대사같은건 그냥 현대로맨스 같아요 ^^ 재미는 있는데 읭?하게 되네요',
#     'sympathyCount': 21,
#     'antipathyCount': 3}]},
#  '8365155': {'title': '홍등가의 소드마스터',
#   'star_score': 7.3,
#   'liked': 127,
#   'author': '망신창이',
#   'publisher': '문피아',
#   'age_rating': '12세 이용가',
#   'sObjectId': '466209_0',
#   'comment_list': [{'contents': '큰 교훈이군요 시리즈 아이디는 절대 공유하지 않겠습니다',
#     'sympathyCount': 915,
#     'antipathyCount': 12},
#    {'contents': '??: 이것이 우리 제국이 숨기고 있는 힘이다. 제국도 알지 못 하지.',
#     'sympathyCount': 687,
#     'antipathyCount': 9},
#    {'contents': '그와중에 그럴싸한 사무실의 책상도 잘라먹었네ㅋㅋㅋ',
#     'sympathyCount': 653,
#     'antipathyCount': 7},
#    {'contents': '뛰어난 재능을 가진 아이를 본 마법사는 아이를 재료로 생체 아티팩트를 만드려하고,뛰어난 재능을 가진 아이를 본 기사는 위대한 경지에 도달할 아이의 스쳐지나가는 가르침이어도 베풀 수 있다는 것에영광을 느낀다.',
#     'sympathyCount': 635,
#     'antipathyCount': 8},
#    {'contents': '다른 소설은 모르겠는데, 이 소설은 증명시켜줄것 같다',
#     'sympathyCount': 616,
#     'antipathyCount': 9},
#    {'contents': '시리즈 쉑들 이작품 수입한 이유가 이번화 때문인것 같은데',
#     'sympathyCount': 605,
#     'antipathyCount': 5},
#    {'contents': '고아수집가에서 고아메이커로 진화했네ㅋㅋㅋㅋㅋ',
#     'sympathyCount': 589,
#     'antipathyCount': 6},
#    {'contents': '리엑션 장인 로필렌이 이 소식을 들으면 그런 역사적인 순간에 자기만 없었다며 바로 새롭게 오열 리엑션 들어감ㅋㅋㅋㅋㅋ',
#     'sympathyCount': 580,
#     'antipathyCount': 5},
#    {'contents': '훌륭한 대학원생의 자질을 발견한 교수님..',
#     'sympathyCount': 579,
#     'antipathyCount': 5},
#    {'contents': 'A: 팀장님, 막내가 그랜저 타고 왔습니다팀장: 막내가 그랜저 타는게 뭐 어때서? 신경 꺼 꼰대도 아니고A: 각그랜저인데요?팀장: 뭐? 야 나가보자 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#     'sympathyCount': 570,
#     'antipathyCount': 3}]},
#  '4153395': {'title': '공작님, 회개해주세요!',
#   'star_score': 9.2,
#   'liked': 59,
#   'author': '별볆볆별명',
#   'publisher': '글고운',
#   'age_rating': '전체 이용가',
#   'sObjectId': '361308_0',
#   'comment_list': [{'contents': '역대급 명대사 ㅋㅋㅋ "니가 우리 가족에 대해 뭘알아!!".. ㅋㅋㅋㅋ 댓글 안달수없었음.. 그렇지 남의 가족을 니들이 어떻게 알아 ㅋㅋㅋ',
#     'sympathyCount': 422,
#     'antipathyCount': 4},
#    {'contents': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ완벽주의 상사에게 내 땡땡이가 들킨 건에 대하여',
#     'sympathyCount': 397,
#     'antipathyCount': 6},
#    {'contents': '그러니까... 저 서스펜스가 말랑뽀쟉 냥냥이처럼 된다 이거죠...? 이 소설은 힐링물이고...? 퍽이나 믿겠다. ...아냐 믿어봐야지. 지키기는 무슨 공격만 할 듯이 사나웠던 한이가 순하게 웃거나 지키려고 하고 금방이라도 독자 죽일 것 같던 중혁이가 동료가 된 것처럼... 가능성 있어... 응...',
#     'sympathyCount': 243,
#     'antipathyCount': 4},
#    {'contents': '자기한테 계속 썼네... 어릴때부터 감정적으로 힘들거나 하면 신성력으로 안정시킨거구나',
#     'sympathyCount': 241,
#     'antipathyCount': 1},
#    {'contents': '크흡ㅋㅋ들킨거?ㅋㅋ 이래서 눈치빠른 상사는 힘들다니까ㅋ',
#     'sympathyCount': 222,
#     'antipathyCount': 2},
#    {'contents': '책 줄거리 다 알려주네요 길다 길어...그런데 성검의 주인 책으로 읽었으면 대게 재미없었을 거 같아요. 성검 주인 주인공 진실도 모른채 뻘짓하며 돌아다니다가 적들에게 놀아나 친구랑 싸우고, 친구 살려둬서 큰적되고 마왕 1초 강림. 보스 죽였는데 세상은 이미 풍비박산 완전 고구만데...',
#     'sympathyCount': 210,
#     'antipathyCount': 0},
#    {'contents': '나 저 상황이면 벌써 창문열고 기차에서 뛰어내렸다',
#     'sympathyCount': 201,
#     'antipathyCount': 0},
#    {'contents': '...? 뭔진몰라도 그거 아니에요ㅋㅋㅋ',
#     'sympathyCount': 195,
#     'antipathyCount': 2},
#    {'contents': '한스 가정폭력 방조가맞지뭐.. 근데 시온ㅋㅋㅋㅋㅋ스콘 위아래라니 방심하다 터졌다ㅋㅋ',
#     'sympathyCount': 190,
#     'antipathyCount': 0},
#    {'contents': '주인공 아무말대잔치ㅋㅋㅋㅋㅋㅋ 역사와 전통이 있는 개판ㅋㅋㅋㅋㅋㅋㅋ',
#     'sympathyCount': 188,
#     'antipathyCount': 1}]},
#  '9543503': {'title': '아름다운 톱가수',
#   'star_score': 3.7,
#   'liked': 2,
#   'author': '길밖의새',
#   'publisher': 'HIT',
#   'age_rating': '전체 이용가',
#   'sObjectId': '501801_0',
#   'comment_list': [{'contents': '아 그래서 이번편 제목이 저렇구나 ㅋㅋ와세다 ㄲㅓ ㅈㅖ',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '그래 넌 찬익이한테 고마워해야해 ', 'sympathyCount': 0, 'antipathyCount': 0},
#    {'contents': '주변에 넘끌려다니는거 같아 ㅠㅠ ', 'sympathyCount': 0, 'antipathyCount': 0},
#    {'contents': '펍 아 그냥 가라 에궁 왜그리 진상이니',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '잘가 펍 ', 'sympathyCount': 1, 'antipathyCount': 0},
#    {'contents': '야 만든다고 했지 준다고 안했잔아 주지마저런 싹퉁바가지들을 봤나 ',
#     'sympathyCount': 1,
#     'antipathyCount': 0},
#    {'contents': '역시 앵무는 꼭 있어야하네 ', 'sympathyCount': 1, 'antipathyCount': 0},
#    {'contents': '아베 잘가 ㅋㅋ 에구 바보', 'sympathyCount': 1, 'antipathyCount': 0},
#    {'contents': '와세다 인지 짱난다', 'sympathyCount': 1, 'antipathyCount': 0},
#    {'contents': '멋지네 ', 'sympathyCount': 0, 'antipathyCount': 0}]},
#  '9251475': {'title': '재벌집 만렙 아들',
#   'star_score': 8.9,
#   'liked': 20,
#   'author': '오소록',
#   'publisher': '제이트리',
#   'age_rating': '전체 이용가',
#   'sObjectId': '492380_0',
#   'comment_list': [{'contents': '장군 국적이 알고보니 왜국이었나 ㅋㅋㅋㅋㅋ',
#     'sympathyCount': 116,
#     'antipathyCount': 2},
#    {'contents': '아이고 ㅋㅋㅋㅋ 마포구 중동 ㅋㅋㅋㅋ',
#     'sympathyCount': 81,
#     'antipathyCount': 0},
#    {'contents': '저시대에는 저나이대의 아이에게 담배. 술. 복권 같은 거 심부름이 가능했던 시절이기에 파시는 분도 그냥 줍니다.',
#     'sympathyCount': 76,
#     'antipathyCount': 0},
#    {'contents': '읽으면서 빵 터졌네ㅋㅋㅋㅋ계약서가 x으로 보이시나 ㅋㅋㅋㅋ',
#     'sympathyCount': 46,
#     'antipathyCount': 1},
#    {'contents': '나도 초중고 때까지 입가심으로 은단을 먹었음.할머니가 나눠주셔서 먹기 시작했는데, 입에 맞아서 거의 중독이었음. 그땐 동네수퍼나 구멍가게에서도 안약병 비슷한 데 넣어 팔았는데, 먹다보니 향이 약해서 약국에서 고려은단 사먹음. 고등학교 땐 하루에 한통씩 먹었는데... 국민학교 때 작은 거 한통에 백원인가 하던게 나중엔 수십배 올라서 대학교 들어가면서 끊음. 대신에 민트랑 차에 빠짐.',
#     'sympathyCount': 46,
#     'antipathyCount': 1},
#    {'contents': '작가님~이 당시에는 구의원 시의원 없습니다... 구의원 시의원은 김영삼때 지방자치제가 도입되면서 시작되었거든요',
#     'sympathyCount': 36,
#     'antipathyCount': 3},
#    {'contents': '뭐 어떰? 어차피 이런소설 비현실적인 요소 감안하구 보는거구만 난 개꿀잼 ㅋㅋ현실성 따지려면 이런류 앱소설 보면 안되는거지',
#     'sympathyCount': 35,
#     'antipathyCount': 2},
#    {'contents': '분당...판교...수서...19만...진도준이냐',
#     'sympathyCount': 30,
#     'antipathyCount': 2},
#    {'contents': '전생이 김충선 ??임진왜란때 귀화한 왜구출신 장수 김충선이면 인정..',
#     'sympathyCount': 27,
#     'antipathyCount': 1},
#    {'contents': '엄마가 모자란게 아니고 70년대부터 80년대 90년대에는 사람들이 다 순수했다 이웃간에 정도 있었고 진짜 살기 좋았다 ',
#     'sympathyCount': 25,
#     'antipathyCount': 0}]},
#  '9518956': {'title': '천재 귀환자의 힐링카페',
#   'star_score': 8.6,
#   'liked': 3,
#   'author': '호오르혜',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '501043_0',
#   'comment_list': [{'contents': '아 진짜....1년 뒤 일어난 거 진짜 생각보다 많이 신경 쓰이네요? 아버지가 저렇게 다정한데 어떻게 애가 일어나서 놀라고 병원부터 가자는 소릴 안 하시는지...아님 제가 그런 얘길했는데 도현이가 거부했다는 걸 못 봤나요....?',
#     'sympathyCount': 30,
#     'antipathyCount': 1},
#    {'contents': '1년동안 누워있던 아들이 창고정리하고 가게 준비 도운게 철든것 같아서 기분 이상한거로 끝날 일이냐고ㅋㅋ 뭔가 억지 힐링을 강제로 구겨서 주입하려는 느낌?',
#     'sympathyCount': 17,
#     'antipathyCount': 1},
#    {'contents': '1년을 누워있었으면 병원에 가야하지 않나요?',
#     'sympathyCount': 16,
#     'antipathyCount': 4},
#    {'contents': '스킬이라면서 치유 마법은 왜 나오나요 애초에 스킬이라는 단어 자체가 어색합니다 그리고 아버지 반응이 겨우 저런거도 이해가 안가네요 무슨 1년 여행 다녀온거도 아니고 .. 가망없이 누워있다가 저렇게 일어나면 가게 문 닫고 바로 119 부르던가 병원을 데려가는게 정상 아닌가요 현실성이 너무 부족한거 같습니다',
#     'sympathyCount': 11,
#     'antipathyCount': 2},
#    {'contents': '수많은 판타지 웹소설에서 고양이 사료 먹는 드래곤 첨일세. ',
#     'sympathyCount': 10,
#     'antipathyCount': 0}]},
#  '9174710': {'title': '재벌집 천재 감독',
#   'star_score': 8.6,
#   'liked': 34,
#   'author': '산경(山景)',
#   'publisher': 'JHS BOOKS',
#   'age_rating': '전체 이용가',
#   'sObjectId': '490330_0',
#   'comment_list': [{'contents': '달동네 1화 선발대들 평이50화까지 정말 재밌는데 50화부턴 소설이 대본집으로 변해서 대본 지문 대사 디렉팅으로 10화 뚝딱 날라간다는 평이 많습니다 다른 선발대들도 대본으로 분량채우는 거에 관련해 비판이 꽤 있네요 초반부는 재밌다고 합니다 저는 200화쯤 나오면 선발대 여론보고 구울예정입니다',
#     'sympathyCount': 194,
#     'antipathyCount': 0},
#    {'contents': '무료부분만 볼만하다 급격히 무너짐 자기 작품인 재벌집 막내아들 성공했다고 어중간하게 연예계로 비틀어서 쓴거 같은데 최악임',
#     'sympathyCount': 160,
#     'antipathyCount': 6},
#    {'contents': '아니 드라마대사로 몇화를 쓰는겁니까 안읽혀집니다 구매한거 그냥 다넘기는중입니다 흐름만 끊기고 ',
#     'sympathyCount': 130,
#     'antipathyCount': 14},
#    {'contents': '아 뭔소리지 했는데 대본으로 분량먹는다는 댓글이 이해가 가네.... 여기부터 시작인가...',
#     'sympathyCount': 120,
#     'antipathyCount': 2},
#    {'contents': '소설 내용이랑 흐름과 관계없는 대본 지문이 너무 많은것 같네요, 무료라서 소설속 드라마 보는 느낌으로 읽을수는 있는데 100원씩 내면서 보기에는 조금 힘들겠어요.드라마 작가에 도전하기 전 에피소드 대본 연습 하시려는 느낌이 들고, 에피소드 대본 습작을 돈내고 볼 수 는 없어서,하루에 한편씩 무료일때 까지만 즐겨보아야겟어요.',
#     'sympathyCount': 84,
#     'antipathyCount': 1},
#    {'contents': '작품 속에 작품은주인공의 삶과 밀접한 관련이 있을 때 흡입력이 살아납니다.작품을 하면서 깨달음을 얻거나 작품 속 상황이 주인공 삶과 닮아 있을 때 특히 그렇습니다.작가님은 탈출과 콜렉션을 등장시켰을 때 철저히 주인공 능력을 전개하는 요소로 사용했습니다. 저도 그게 좋았구요꾼은 어떤가요? 이번화가 다수의 독자들을 만족시킬 수 있을거라고 확신하시나요?',
#     'sympathyCount': 83,
#     'antipathyCount': 5},
#    {'contents': '보기도 짜증나는 로멘스를 욱여넣은 jtbc를 까는 것인가생각보다 로멘스가 적어서 실망한 작가의 투영인가...',
#     'sympathyCount': 77,
#     'antipathyCount': 0},
#    {'contents': '난 지금까지 메인스토리랑 세 개의 대본 중에 메인스토리가 제일 좋은데 대본은 왜 자꾸 넣는 건지,, 대본도 재미는 있는데 제 취향이 아니거든여... 전 현판을 좋아해서 웹소설을 보는데 왜 조폭 영화 대본을 보여주시려는 건지 모르겠습니다. 다시 말하지만 대본도 재밌어요. 근데 제가 기대한 내용이 아니라는 거죠. 제가 선호하지 않는 웹소설이라는 뜻입니다. 아무리 로맨스 웹소설이 재밌다고 해도 그건 잘 안 보는 것처럼요. 안그래도 좋아하는 소재에 직업물에 제가 좋아할만한 건 다 들어갔는데 조폭물은 영화도 잘 안 본다고요... 이래서 자꾸 사람들 평이 갈리는 듯. ',
#     'sympathyCount': 66,
#     'antipathyCount': 6},
#    {'contents': '원작 작가님 드라마 논의 단계부터 많이 화나셨나봄.. 이리 큰그림을 그리고 계셨다니',
#     'sympathyCount': 57,
#     'antipathyCount': 1},
#    {'contents': '작가님 그 희귀한 여성 독자가 접니다. 드라마 제작 나오기 전에 다 읽었어요. 산경 작가님 재벌집 막내아들은 현판 파는 사람들한테 유명합니다. 너무 재밌어요. 더 주세요. ',
#     'sympathyCount': 57,
#     'antipathyCount': 6}]},
#  '9319558': {'title': '숨만 쉬어도 무공이 생겨',
#   'star_score': 8.3,
#   'liked': 3,
#   'author': '정주(丁柱)',
#   'publisher': '라온E&M',
#   'age_rating': '전체 이용가',
#   'sObjectId': '494576_0',
#   'comment_list': [{'contents': '저가요. 어제 댓글 쓴 대로오늘 2편 예약을 진짜 할라고 했는데요.한 천 자 정도 부족해서 말이죠..1편밖에 못 올립니다.일단 내일은 당연히 올라오고, 2편 예약 할 수 있도록 최선 다하겠습니다.약속을 남발했다가 못 지키면 멘탈이 터지는 개복치 멘탈인 관계로최선을 다하지만, 확답은 하지 않겠습니다.어제도 분명 되는 줄 알았는데 ㅠㅠ',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '어제 본가에 갔다왔더니 근육통으로 내일 2회올리겠습니다.유통 마감 시간에 맞출 수가 없네요...내일 2개 나갑니다! 미리 예고 합니다!',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '와 식신으로 이미지 궅혀지는건가!? 나쁘지 않아! 너무 좋아요! ㅎㅎ 최신편부터 1화까지 다시 정주행 했는데 너무 좋네요 작가님 다음 화도 ㅎ하이팅!(댓을 잘 안달아도 열심 달리고 있습니돠!♪＼(^O^)/(*^_^*)＼(^O^)/ )',
#     'sympathyCount': 1,
#     'antipathyCount': 0},
#    {'contents': '오호 공영두펫이 저리 된거였군요? ',
#     'sympathyCount': 1,
#     'antipathyCount': 0},
#    {'contents': '아으.. 고민이다 지를까.. 아니면 나중의 기쁨을 위해 중단..? 끙.. 몰랏 지른닷! ',
#     'sympathyCount': 1,
#     'antipathyCount': 0},
#    {'contents': '꺅 ㅎㄷㄷ? 이제부터 호러인가!?', 'sympathyCount': 1, 'antipathyCount': 0},
#    {'contents': '어우 속이 다 시원하네 역시 참았다 보는게 꿀맛이구로 기달려서 보는게 지옥이지만.. 재밌습니돠!!',
#     'sympathyCount': 1,
#     'antipathyCount': 0},
#    {'contents': '시간 내 마감 실패로 토요일로,+ 노동절 정상영업 합니다',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '몸살로하루만 더 쉬겠습니다.', 'sympathyCount': 0, 'antipathyCount': 0},
#    {'contents': '두통으로 하루만 더 쉬겠습니다.',
#     'sympathyCount': 0,
#     'antipathyCount': 0}]},
#  '9553143': {'title': '이탈리아에서 살아남기',
#   'star_score': 8.0,
#   'liked': None,
#   'author': '포렴',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '502090_0',
#   'comment_list': [{'contents': '이거 문체가 담담해서 깨닫기 힘든데 동로마제국 이탈리아에서 부활 너무 웃김',
#     'sympathyCount': 19,
#     'antipathyCount': 2}]},
#  '9509566': {'title': '남주의 애인을 꼬셔버렸습니다 [독점]',
#   'star_score': 8.4,
#   'liked': 7,
#   'author': '헤샤',
#   'publisher': '해피북스투유',
#   'age_rating': '15세 이용가',
#   'sObjectId': '500779_0',
#   'comment_list': [{'contents': '지금의 여주는 영혼이 바뀌었으니 독먹인 본인이 아니고, 뭣보다 꽤 어릴때 같은데 재물이 많은것도 고위귀족인 것도 아닌 어린 여자애가 마법사한테 영향을 끼칠만한 독을 어디어 구해서 먹일생각을 했을까 싶은데 말이죠. 진짜 마리아를 누가 이용한건 아닐까. 분노가 향할 방향이 잘못 됬든지 제일 만만하니 희생양이 됬든지..? 당장 시계도 못사는 집에서, 그 전에는 좀 더 재산이 있긴 했겠지만 그래도 고위귀족도 아니고 나이가 어린애가 부모님도 모르게 용의주도하게 마법사에게 통하는 독을 구한다는것 부터가 말이 안되는데....거기다 원래 마리아의 성격은 소심 심약 자체인것 같으니 더 앞뒤가 안맞는 느낌인데 말이죠..,',
#     'sympathyCount': 49,
#     'antipathyCount': 3},
#    {'contents': '안녕하세요 헤샤입니다. 네이버 독자님들께 처음으로 인사드리게 되어 정말 긴장되고 설레는데요! 여러분들이 재밌게 보고 즐거워하셨으면 좋겠습니다. 감사드리고 사랑합니다!! ',
#     'sympathyCount': 48,
#     'antipathyCount': 0},
#    {'contents': '아니 애당초 왜 아무도 이상하다고 생각을 안한건데? 어리고 재산도 권력도 없는 가난한 귀족집 영애가 무슨 수로 그렇게 대단하고 귀한 독초를 찾아 사는데?',
#     'sympathyCount': 42,
#     'antipathyCount': 0},
#    {'contents': '겁나 소름끼침 와 나는 일도 맘이 없는데 아름답다는 이유로 성희롱 당하고 구애 당하구 이성애자인데 동성들한테 성적 폭력을 당하면 기분 진짜 엿같아기분이 나도 이렇게 드러운데 ',
#     'sympathyCount': 38,
#     'antipathyCount': 0},
#    {'contents': '....너무기가막혀서 말이 안나오네. 저거...어린 마리아를 이용해 독 먹인게 사실 저놈 아닐까...',
#     'sympathyCount': 33,
#     'antipathyCount': 0},
#    {'contents': "여주 항상 싸가지 운운하는데 정작 본인이 제일 싸가지 없다는건 모르는듯..본인이 사고친거에 피해본 상대가 화내면 '아니, 내가 잘못하긴 했는데 솔직히 저렇게 화낼 정도는 아니지 않나? 예민미쩌네; 개싸가지' 이러면서 본인이 잘못한걸 상대방의 기준이 아니라 본인의 기준으로 멋대로 판단하며 씹어대고 본인 기분 조금만 어긋나면 본인은 아무 잘못 없는 선량한 피해자로 생각하고 상대는 악당 취급하질 않나 이걸 내로남불이라고 해야하나 자기 합리화라고 해야하나..지금도 이안이 위험 감수하고 도와준건데 그런 사람을 상대로 속으로 똥강아지 취급에 본인이 사고친거 뒷수습 다 해주고 치료까지 해주고나서 위험하다고 주의 주는걸 쓸데없는 잔소리 취급하질 않나..그냥 클로드가 상대적으로 더 쓰레기라 가려져서 그렇지 여주도 하는 꼴 보면 만만찮음.. 완전체 같은 느낌이라고 해야하나..정확히 내가 싫어하는 타입의 인간이라 그냥 여주 인성은 잘라먹고 스토리만 본다 생각하고 흐린눈으로 보는 중임..",
#     'sympathyCount': 25,
#     'antipathyCount': 2},
#    {'contents': "여기저기 조사들이 빠지거나 맞지 않는게 쓰이기 일쑤고 중간중간 아작낸다던지 *랄 옘병 한다는 등의 어투가 전체적으로 작품 분위기를 가볍게 만드네요.이번에 나온 신작 3개 중에서 소재가 제일 재밌어 보여서 읽는데 .. 음.. 뭐랄까 약간 'ㄹㅇ ㅋㅋ~ 뚝배기를~' 같은 느낌의 로판보다는 현판에 어울릴 법한 가벼운 언행들로 이루어진 구성에 더해 계속해서 빠지거나 맞지 않는 조사들의 쓰임, 초반인데도 애매하다고 느껴지는 몇몇 개연성의 부재 같은 것들이 전체적으로 작품 퀄리티가 떨어진다는 느낌을 주네요.어지간하면 조사 관련 오타가 나도 사람인데 실수 할 수 있지 하면서 그냥 보는 편인데 한 편에 한 두개도 아니고 수두룩하게 나오니 보다가도 자꾸 집중이 흐트러지고, 여주는 양아치 마냥 언행이 가벼워 전체적인 몰입도도 떨어지고.무엇보다 여주의 인성, 캐릭터성, 성격이 호감형이냐 하면 딱히 그것도 아니고.단순히 최근 제가 봐오던 소설들과는 결이 달라서 그런가 싶어 조금 더 봐야 알겠네요.",
#     'sympathyCount': 22,
#     'antipathyCount': 1},
#    {'contents': '현 공작은 데릴사위주제에오만함의 극치네. 제정신인가?',
#     'sympathyCount': 21,
#     'antipathyCount': 0},
#    {'contents': '....(욕)(심한욕)(매우심한욕)저딴게 원작 남주라고?',
#     'sympathyCount': 20,
#     'antipathyCount': 0},
#    {'contents': '소식듣고 왔어요!! 꺄아악!!! 근데 표지에 여주가 남주 멱살 잡으면서 웃고 있네요!ㅋㅋㅋㅋ 너무이뻐(?)',
#     'sympathyCount': 19,
#     'antipathyCount': 0}]},
#  '9576221': {'title': '말단 병사가 2회차를 숨김',
#   'star_score': 8.5,
#   'liked': 3,
#   'author': '2차자아',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '502810_0',
#   'comment_list': [{'contents': '소설 주인공이야 작가버프로 개연성 파괴하고 승승장구하지만 우리가 그러면? 그 유명한 형님 이새끼 웃는데요? 앤딩임...',
#     'sympathyCount': 20,
#     'antipathyCount': 0},
#    {'contents': '직장인하던사람이 10년만에 기사되고 오러깨우친거면 쌉재능러 같은데',
#     'sympathyCount': 16,
#     'antipathyCount': 0}]},
#  '8898758': {'title': '용병이 되었다 [독점]',
#   'star_score': 6.1,
#   'liked': 1,
#   'author': '화산뿔멧돼지',
#   'publisher': '알에스미디어',
#   'age_rating': '전체 이용가',
#   'sObjectId': '483841_0',
#   'comment_list': [{'contents': '현재 나와있는 18화까지 보고 왜 평점이 낮은지 확실히 알게됨이 소설만의 고유 설정, 단어, 그와 관련된 사건들이 많음그걸 알아갈 시간을 안주고 짧은 지면에 다 때려넣음독자는 모르는게 나오면 그걸 다 외우는게 아니라중요하게 설명되는걸 우선 기억하고 나머지는 반복해서 보는걸로 머리속에 넣는건데마대자루에서 쓰레기 버리듯이 우르르 쏟아내면 뭐를 기억해야하나다 기억하고 넘어가야하나 고민할만큼의 재미도 없음작가가 머리속으로 그리는 멋있음이 뭐지는 알겠는데표현방법이 너무 후짐작가도 목표로 하는 재미있게 본 판무 있을텐데그 소설에서 이런식으로 설정을, 떡밥을 풀어나갔는지 생각해보길',
#     'sympathyCount': 43,
#     'antipathyCount': 1},
#    {'contents': '반이 투레질을 했다고요..? 투레질은 말이 하는 거잖아요..',
#     'sympathyCount': 13,
#     'antipathyCount': 1}]},
#  '9599215': {'title': '아포칼립스에 집을 숨김',
#   'star_score': 9.2,
#   'liked': 26,
#   'author': '로드워리어',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '503591_0',
#   'comment_list': [{'contents': '🔥전설의 아포칼립스 명작 드디어 시리즈 상륙!🔥문피아 무료1위 유료1위 연속 알박, 독자 추천글 역대급 러쉬의 화제의 대작!⭐ 1~11화 : 1화 1에피로 등장인물, 세계관 소개 ⭐ 12화 이후 : 서서히 주인공 중심으로 메인스토리 시작🔥독창적 스토리, 입체적 캐릭터, 비장함, 감동, 유머까지 다 갖춘 아포칼립스 필독서! 해피엔딩 복선 있음! 안보면 인생손해! 🔥개인적인 추천 에피소드 : 캣맘, 재벌, 골드, 빛이 된 남자, 변신, 불멸, 메시아, 거목, 판결 (114화 연재 기준)*️⃣ 이 작가님의 다른 추천 작품 : 주인공이 자비를 숨김, 주인공이 힘을 숨김 (이분이 숨김제목 원조! 재밌으면 같이 읽어보세요!^.^)',
#     'sympathyCount': 362,
#     'antipathyCount': 63},
#    {'contents': '뭔가 일부러 밉상소리 하며 몸을 뺀거 같은데? 와서 보고 나니 이건 혼자만의 쉘터라는걸 느낀건가?',
#     'sympathyCount': 210,
#     'antipathyCount': 7},
#    {'contents': '2023년 문피아 최고의 작품',
#     'sympathyCount': 140,
#     'antipathyCount': 33},
#    {'contents': '배가 부른 게 아니고 방공호 보고 들어와도 문제 생길 수밖에 없는 거 느낀 듯 그래서 일부로 싫은 소리 하면서 못 산다고 한 거 같고 죽지만 않으면 좋겠네..',
#     'sympathyCount': 135,
#     'antipathyCount': 2},
#    {'contents': '계산이 빠른거지... 어떻게든 비비고 들어와도 탈이 날 수 밖에 없다는걸.가족끼리 있어도 프라이버시 없으면 문제가 생기는데...사실상 인간사냥꾼이랑 비슷하게 사회부적응자인 쥔공이랑 같이 있으면 둘중에 하나는 마빡을 도끼 수납장으로 쓰게 될거임.',
#     'sympathyCount': 120,
#     'antipathyCount': 4},
#    {'contents': '헐 죽으라고 민물에 넣은거였어ㅜㅜ',
#     'sympathyCount': 116,
#     'antipathyCount': 3},
#    {'contents': '인간 사냥꾼 자꾸 보니까 정들 것 같음ㅋㅋㅋㅋㅋ ',
#     'sympathyCount': 115,
#     'antipathyCount': 5},
#    {'contents': '질질 안 끌고 분랑늘리기 장난없이 짧은 회차속에 넣을거 다 넣으니 좋네',
#     'sympathyCount': 110,
#     'antipathyCount': 0},
#    {'contents': '이번 편은 꽤나 슬프다', 'sympathyCount': 102, 'antipathyCount': 7},
#    {'contents': '이미 자신이 죽이려 했기 때문에 광분한거네 ',
#     'sympathyCount': 97,
#     'antipathyCount': 1}]},
#  '9360005': {'title': '파천옥녀제왕도',
#   'star_score': 8.9,
#   'liked': 1,
#   'author': '필걸',
#   'publisher': 'JC미디어',
#   'age_rating': '15세 이용가',
#   'sObjectId': '496163_0',
#   'comment_list': [{'contents': '별점이 점점 올라가네... 함 읽어볼까?',
#     'sympathyCount': 0,
#     'antipathyCount': 0},
#    {'contents': '그림은 남매인데..(아직 읽기전)',
#     'sympathyCount': 1,
#     'antipathyCount': 1}]},
#  '9633528': {'title': '재벌녀의 두 번째 남편',
#   'star_score': 7.4,
#   'liked': 7,
#   'author': '악중선',
#   'publisher': '문피아',
#   'age_rating': '전체 이용가',
#   'sObjectId': '504456_0',
#   'comment_list': [{'contents': '전아내 예기좀 그만하면 안됩니까?글쓴이마음도 이해는간다만...여긴소설이잖아요...일기장이아닙니다..',
#     'sympathyCount': 38,
#     'antipathyCount': 9},
#    {'contents': '문체나 문장이 거친데 묘하게 현장감이 있음. ',
#     'sympathyCount': 10,
#     'antipathyCount': 1}]}}
